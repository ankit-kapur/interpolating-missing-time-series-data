# %% [markdown]
# # Cleaning the datasets
#
# ### Importing libraries

# %%
# Numpy
import numpy as np
from numpy import concatenate, array
from numpy.random import randn
# Decimal precision value to display in the matrix
np.set_printoptions(precision=5, suppress=True)

# Scipy
import scipy
import scipy.stats as stats

# Matplotlib
import matplotlib.cm as cm
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
#mpl.rc('figure', figsize=(10, 8))

# Pandas experiments
import pandas as pd
from pandas import Series, DataFrame, Panel

# Misc
import time
import datetime as dt
import math
import random
# import seaborn as sns
print 'All libraries loaded.'
# Out:
# All libraries loaded.

# %% [markdown]
# # Make dataframes from data

# %%
# Make dataframes from data

# eGFR data
egfr_df = pd.read_csv('~/code/independent/datasets/cdr_gfr_derived.csv', parse_dates=['resultdata'])
egfr_df.drop('gfr', axis=1, inplace=True)
egfr_df.columns = ['pid', 'timestamp', 'gender', 'birthyear', 'age', 'gfr']

# Findings data
findings_df = pd.read_csv('~/code/independent/datasets/cdr_finding.csv', parse_dates=['finddate'], usecols=['idperson', 'finddate', 'valuename', 'findvalnum'])
findings_df = findings_df[['idperson', 'finddate', 'valuename', 'findvalnum']]
findings_df.columns = ['pid', 'timestamp', 'testname', 'testval']

# Lab reports data
lab_df = pd.read_csv('~/code/independent/datasets/cdr_lab_result.csv', parse_dates=['resultdate'], usecols=['idperson', 'resultdate', 'valuename', 'resultvaluenum'])
lab_df = lab_df[['idperson', 'resultdate', 'valuename', 'resultvaluenum']]
lab_df.columns = ['pid', 'timestamp', 'testname', 'testval']
# Make all lab tests values uppercase
lab_df.testname = map(lambda x: x.upper(), lab_df.testname)

# %%
# Normalize dates (to remove the time part of it)
egfr_df.timestamp = egfr_df.timestamp.map(pd.datetools.normalize_date)
findings_df.timestamp = findings_df.timestamp.map(pd.datetools.normalize_date)
lab_df.timestamp = lab_df.timestamp.map(pd.datetools.normalize_date)

# %%
# NaN values
total_rowcount = len(lab_df.testval.values)
nan_rowcount = len([x for x in lab_df.testval.values if math.isnan(x)])
print '\n',(str(nan_rowcount*100/total_rowcount)+ "% of the values are NaN")

# Drop NaN rows
# lab_df.dropna(inplace=True)
# Out:
# 1% of the values are NaN

# %% [markdown]
# ## Make a multi-index/hierarchical index
# #### The index will be a combination of the PID (person ID) and timestamp

# %%
# Set the index as a combination of the person ID and timestamp
egfr_df.set_index(['pid', 'timestamp'], inplace=True)
findings_df.set_index(['pid', 'timestamp'], inplace=True)
lab_df.set_index(['pid', 'timestamp'], inplace=True)

# %% [markdown]
# ## Get list of all patients for whom we have eGFR data

# %%
list_of_patients = list(set(egfr_df.index.get_level_values('pid').values))
print '\nFound', len(list_of_patients), 'unique patients'
# Out:
# Found 63215 unique patients

# %% [markdown]
# ## Make the new dataframe (empty)

# %%
# Column names will be a combination of all the lab test names and finding names
unique_findings = set(findings_df.testname.values)
unique_labtests = set(lab_df.testname.values)
print '\nFindings:', list(unique_findings)
print 'Lab tests:', list(unique_labtests)
final_col_names = np.append(list(unique_findings), list(unique_labtests))
# Out:
# Findings: ['FND_WTLB', 'FND_BPS', 'FND_BPD', 'FND_HTIN']
# Lab tests: ['LR_AST', 'LR_MICROCR', 'LR_HDL', 'LR_TRIG', 'LR_A1C', 'LR_CR', 'LR_PTH', 'LR_GLUCNONFAST', 'LR_GLUCFAST', 'LR_LDL', 'LR_GFR', 'LR_VITD 25', 'LR_ALT', 'LR_VITD 1_25', 'LR_PHOS', 'LR_GFR_AFRAMER']

# %%
# Row locations in the eGFR dataframe of patients
# locations_of_patients = []
# for patient in list_of_patients:
#     get_loc_result = egfr_df.index.get_loc(patient)
#     locations_of_patients += [i for i,v in enumerate(get_loc_result) if v == True]

# combined_df = DataFrame(egfr_df.iloc[locations_of_patients])
combined_df = pd.DataFrame(egfr_df)

# Add the new columns
for newcol in final_col_names:
    combined_df[newcol] = np.nan

# %% [markdown]
# ## Fill values into the new dataframe<br>based on joins on the other dataframes

# %%
def fill_data(source_df, patient_id):
    
    ############### Could optimize
    locations_of_patients = []
    if str(patient_id) in source_df.index:
        
#         get_loc_result = source_df.index.get_loc(str(patient_id))
#         locations_of_patients += [i for i,v in enumerate(get_loc_result) if v == True]
#         this_patients_data = source_df.iloc[locations_of_patients]
        this_patients_data = source_df.loc[str(patient_id)]

        # We only need data for the dates that exist in the combined DF already 
        # (the ones that have eGFR readings)
        for timestamp in combined_df.loc[patient_id].index:
            if timestamp in this_patients_data.index.get_level_values('timestamp'):
                this_patient = this_patients_data.loc[timestamp]

                # Set the value in the DF for this test
                # Check if there's multiple values for the same timestamp
                if type(this_patient) == pd.core.frame.DataFrame:
                    for i in range(this_patient.testname.size):
                        
                        try:
                            combined_df.loc[(patient_id, timestamp), this_patient.testname[i]] = this_patient.testval[i]
                        except:
                            print 'multivalues for', patient_id
                else:
                    combined_df.loc[(patient_id, timestamp), this_patient.testname] = this_patient.testval

                    
fill_count = 0
start_time = time.time()
lastseen_time = time.time()

for patient_id in list_of_patients:
    
    if fill_count % 500 == 0:
        elapsed_time = time.time() - lastseen_time
        lastseen_time = time.time()
        print 'Data fill for', fill_count, 'patients completed in', '{:.3f}'.format(elapsed_time), 'seconds'
    fill_count += 1
    
#     ########################################## REMOVE
#     if fill_count < 14001:
#         continue
    
    # Check if the findings df has data about this patient
    fill_data(findings_df, patient_id)

    # Check if the lab-tests df has data about this patient
    fill_data(lab_df, patient_id)
    
    
elapsed_time = time.time() - start_time
print 'Task completed in', '{:.3f}'.format(elapsed_time), 'seconds'
# Out:
# Data fill for 0 patients completed in 0.000 seconds
# Data fill for 500 patients completed in 157.239 seconds
# Data fill for 1000 patients completed in 213.652 seconds
# Data fill for 1500 patients completed in 222.478 seconds
# Data fill for 2000 patients completed in 185.968 seconds
# Data fill for 2500 patients completed in 193.586 seconds
# Data fill for 3000 patients completed in 312.431 seconds
# Data fill for 3500 patients completed in 286.072 seconds
# Data fill for 4000 patients completed in 108.058 seconds
# Data fill for 4500 patients completed in 216.104 seconds
# Data fill for 5000 patients completed in 200.301 seconds
# Data fill for 5500 patients completed in 167.326 seconds
# Data fill for 6000 patients completed in 189.163 seconds
# Data fill for 6500 patients completed in 159.524 seconds
# Data fill for 7000 patients completed in 173.184 seconds
# Data fill for 7500 patients completed in 202.893 seconds
# Data fill for 8000 patients completed in 201.204 seconds
# Data fill for 8500 patients completed in 187.568 seconds
# Data fill for 9000 patients completed in 161.909 seconds
# Data fill for 9500 patients completed in 102.594 seconds
# Data fill for 10000 patients completed in 205.001 seconds
# Data fill for 10500 patients completed in 211.467 seconds
# Data fill for 11000 patients completed in 198.721 seconds
# Data fill for 11500 patients completed in 366.801 seconds
# Data fill for 12000 patients completed in 391.553 seconds
# Data fill for 12500 patients completed in 395.091 seconds
# Data fill for 13000 patients completed in 374.604 seconds
# Data fill for 13500 patients completed in 361.509 seconds
# Data fill for 14000 patients completed in 398.993 seconds
# Data fill for 14500 patients completed in 333.498 seconds
# Data fill for 15000 patients completed in 345.667 seconds
# Data fill for 15500 patients completed in 322.146 seconds
# Data fill for 16000 patients completed in 293.105 seconds
# Data fill for 16500 patients completed in 305.442 seconds
# Data fill for 17000 patients completed in 313.564 seconds
# Data fill for 17500 patients completed in 306.500 seconds
# Data fill for 18000 patients completed in 286.189 seconds
# Data fill for 18500 patients completed in 272.511 seconds
# Data fill for 19000 patients completed in 238.100 seconds
# Data fill for 19500 patients completed in 202.393 seconds
# Data fill for 20000 patients completed in 223.702 seconds
# Data fill for 20500 patients completed in 229.119 seconds
# Data fill for 21000 patients completed in 216.275 seconds
# Data fill for 21500 patients completed in 202.001 seconds
# Data fill for 22000 patients completed in 215.894 seconds
# Data fill for 22500 patients completed in 186.689 seconds
# Data fill for 23000 patients completed in 166.108 seconds
# Data fill for 23500 patients completed in 159.558 seconds
# Data fill for 24000 patients completed in 234.436 seconds
# Data fill for 24500 patients completed in 133.703 seconds
# Data fill for 25000 patients completed in 118.619 seconds
# Data fill for 25500 patients completed in 101.937 seconds
# Data fill for 26000 patients completed in 100.217 seconds
# Data fill for 26500 patients completed in 77.772 seconds
# Data fill for 27000 patients completed in 71.503 seconds
# Data fill for 27500 patients completed in 194.490 seconds
# Data fill for 28000 patients completed in 188.034 seconds
# Data fill for 28500 patients completed in 190.362 seconds
# Data fill for 29000 patients completed in 186.915 seconds
# Data fill for 29500 patients completed in 209.735 seconds
# Data fill for 30000 patients completed in 201.761 seconds
# Data fill for 30500 patients completed in 205.000 seconds
# Data fill for 31000 patients completed in 176.638 seconds
# Data fill for 31500 patients completed in 162.003 seconds
# Data fill for 32000 patients completed in 211.911 seconds
# Data fill for 32500 patients completed in 195.723 seconds
# Data fill for 33000 patients completed in 187.154 seconds
# Data fill for 33500 patients completed in 193.700 seconds
# Data fill for 34000 patients completed in 201.457 seconds
# Data fill for 34500 patients completed in 154.712 seconds
# Data fill for 35000 patients completed in 287.534 seconds
# Data fill for 35500 patients completed in 316.693 seconds
# Data fill for 36000 patients completed in 395.328 seconds
# Data fill for 36500 patients completed in 310.821 seconds
# Data fill for 37000 patients completed in 285.302 seconds
# Data fill for 37500 patients completed in 314.900 seconds
# Data fill for 38000 patients completed in 332.532 seconds
# Data fill for 38500 patients completed in 269.367 seconds
# Data fill for 39000 patients completed in 283.313 seconds
# Data fill for 39500 patients completed in 295.087 seconds
# Data fill for 40000 patients completed in 319.552 seconds
# Data fill for 40500 patients completed in 293.819 seconds
# Data fill for 41000 patients completed in 322.625 seconds
# Data fill for 41500 patients completed in 348.704 seconds
# Data fill for 42000 patients completed in 372.841 seconds
# Data fill for 42500 patients completed in 361.579 seconds
# Data fill for 43000 patients completed in 346.648 seconds
# Data fill for 43500 patients completed in 342.155 seconds
# Data fill for 44000 patients completed in 302.357 seconds
# Data fill for 44500 patients completed in 302.559 seconds
# Data fill for 45000 patients completed in 301.010 seconds
# Data fill for 45500 patients completed in 306.892 seconds
# Data fill for 46000 patients completed in 296.613 seconds
# Data fill for 46500 patients completed in 312.740 seconds
# Data fill for 47000 patients completed in 269.324 seconds
# Data fill for 47500 patients completed in 283.229 seconds
# Data fill for 48000 patients completed in 288.181 seconds
# Data fill for 48500 patients completed in 314.556 seconds
# Data fill for 49000 patients completed in 392.872 seconds
# Data fill for 49500 patients completed in 267.942 seconds
# Data fill for 50000 patients completed in 224.908 seconds
# Data fill for 50500 patients completed in 217.713 seconds
# Data fill for 51000 patients completed in 284.350 seconds
# Data fill for 51500 patients completed in 284.105 seconds
# Data fill for 52000 patients completed in 264.882 seconds
# Data fill for 52500 patients completed in 267.166 seconds
# Data fill for 53000 patients completed in 246.578 seconds
# Data fill for 53500 patients completed in 230.882 seconds
# Data fill for 54000 patients completed in 219.585 seconds
# Data fill for 54500 patients completed in 235.208 seconds
# Data fill for 55000 patients completed in 249.749 seconds
# Data fill for 55500 patients completed in 223.591 seconds
# Data fill for 56000 patients completed in 207.464 seconds
# Data fill for 56500 patients completed in 331.089 seconds
# Data fill for 57000 patients completed in 298.897 seconds
# Data fill for 57500 patients completed in 261.798 seconds
# Data fill for 58000 patients completed in 188.757 seconds
# Data fill for 58500 patients completed in 175.205 seconds
# Data fill for 59000 patients completed in 170.996 seconds
# Data fill for 59500 patients completed in 176.524 seconds
# Data fill for 60000 patients completed in 184.057 seconds
# Data fill for 60500 patients completed in 162.113 seconds
# Data fill for 61000 patients completed in 142.827 seconds
# Data fill for 61500 patients completed in 122.384 seconds
# Data fill for 62000 patients completed in 100.923 seconds
# Data fill for 62500 patients completed in 105.511 seconds
# Data fill for 63000 patients completed in 239.892 seconds
# Task completed in 30475.948 seconds

# %% [markdown]
# ## Fill in smoking status values into the dataframe

# %%
# Smoking data
smoke_df = pd.read_csv('~/code/independent/datasets/cdr_history_social.csv', usecols=['idperson', 'valuename'])
smoke_df.columns = ['pid', 'smoker_status']
# Make all lab tests values uppercase
# lab_df.testname = map(lambda x: x.upper(), lab_df.testname)

before_dropping = smoke_df.shape[0]
# Drop duplicate rows 
smoke_df.drop_duplicates(subset='pid', keep='first', inplace=True)
after_dropping = smoke_df.shape[0]
print '\n# of records before dropping duplicates:', before_dropping
print '# of records after dropping duplicates:', after_dropping

# Set the patient ID as the index
smoke_df.set_index('pid', inplace=True)
# Out:
# # of records before dropping duplicates: 1059065
# # of records after dropping duplicates: 63314

# %%
patients_with_smokedata = [x for x in list_of_patients if x in smoke_df.index]
print "\n{:.2f}%".format(len(patients_with_smokedata)*100.0/len(list_of_patients)), 'of the patients have smoking data.'
print 'We will need to impute the missing data for the remaining', "{:.2f}%".format((len(list_of_patients)-len(patients_with_smokedata))*100.0/len(list_of_patients)), 'of the patients.'
# Out:
# 90.99% of the patients have smoking data.
# We will need to impute the missing data for the remaining 9.01% of the patients.

# %%
# Make an empty column for smoker status in the DF
combined_df['smoker_status'] = np.nan

# Fill in smoking status values for all the patients
def set_smoker_status(pid):
    combined_df.loc[(pid), 'smoker_status'] = smoke_df.loc[pid].smoker_status
map(set_smoker_status, patients_with_smokedata)

# %%
# Put the eGFR column last, and bring the smoker_status column in into it's place
col_list = combined_df.columns.tolist()
col_list[3] = 'smoker_status'
col_list[-1] = 'gfr'
combined_df = combined_df[col_list]

# %%
combined_df
# Out:
#                    gender  birthyear  age   smoker_status   FND_WTLB  FND_BPS  \
# pid     timestamp
# 8545332 2006-08-11      F       1924   90  SOC_PastSmoker  152.50000      120
#         2006-11-02      F       1924   90  SOC_PastSmoker  156.00000      118
#         2007-06-05      F       1924   90  SOC_PastSmoker  157.00000      150
#         2010-02-09      F       1924   90  SOC_PastSmoker  163.00000      164
#         2010-08-17      F       1924   90  SOC_PastSmoker  162.00000      135
#         2011-04-13      F       1924   90  SOC_PastSmoker  163.00000      146
# 8545333 2007-05-31      F       1941   73   SOC_NonSmoker  147.00000      130
#         2010-06-10      F       1941   73   SOC_NonSmoker        NaN      NaN
#         2010-06-10      F       1941   73   SOC_NonSmoker        NaN      NaN
# 8545336 2010-11-18      F       1928   86   SOC_NonSmoker  121.00000      147
#         2011-09-01      F       1928   86   SOC_NonSmoker  113.00000      115
# 8545337 2010-10-29      F       1924   90  SOC_PastSmoker        NaN      120
# 8545338 2007-10-11      F       1948   66   SOC_NonSmoker  141.00000      140
# 8545339 2010-05-24      F       1946   68   SOC_NonSmoker  270.00000      155
#         2010-05-24      F       1946   68   SOC_NonSmoker  270.00000      155
# 8545340 2007-04-19      F       1926   88   SOC_NonSmoker  141.00000      140
#         2007-10-01      F       1926   88   SOC_NonSmoker  248.00000      140
#         2007-10-09      F       1926   88   SOC_NonSmoker        NaN      NaN
#         2008-12-18      F       1926   88   SOC_NonSmoker  150.00000      NaN
# 8545341 2006-12-06      F       1943   71             NaN  183.00000      132
#         2007-03-26      F       1943   71             NaN  189.00000      118
# 8545342 2007-02-20      F       1931   83  SOC_PastSmoker  128.00000      106
#         2007-07-19      F       1931   83  SOC_PastSmoker  128.00000      112
# 8545344 2007-11-26      F       1954   60      SOC_Smoker  194.00000      128
# 8545345 2009-06-25      F       1950   64  SOC_PastSmoker  295.00000      106
# 8545346 2009-01-15      F       1950   64   SOC_NonSmoker  128.00000      139
# 8545347 2010-10-29      F       1955   59   SOC_NonSmoker  176.00000      123
#         2010-10-29      F       1955   59   SOC_NonSmoker  176.00000      123
# 8545348 2006-08-10      F       1941   73   SOC_NonSmoker  197.00000      180
#         2009-05-04      F       1941   73   SOC_NonSmoker  182.00000      137
# ...                   ...        ...  ...             ...        ...      ...
# 9581790 2011-05-06      M       1925   89             NaN  107.00136      120
# 9581791 2011-08-29      M       1928   86             NaN        NaN      NaN
# 9581793 2011-09-02      M       1935   79  SOC_PastSmoker        NaN      NaN
#         2011-09-02      M       1935   79  SOC_PastSmoker        NaN      NaN
#         2011-11-08      M       1935   79  SOC_PastSmoker        NaN      NaN
#         2012-02-15      M       1935   79  SOC_PastSmoker        NaN      NaN
#         2012-03-01      M       1935   79  SOC_PastSmoker        NaN      NaN
# 9581799 2011-06-24      M       1926   88             NaN        NaN      NaN
# 9581800 2011-01-06      M       1936   78             NaN        NaN      NaN
#         2011-03-08      M       1936   78             NaN        NaN      NaN
#         2011-08-08      M       1936   78             NaN        NaN      NaN
#         2011-10-18      M       1936   78             NaN        NaN      NaN
#         2012-01-24      M       1936   78             NaN        NaN      NaN
# 9581801 2011-03-30      M       1942   72             NaN        NaN      NaN
#         2011-07-20      M       1942   72             NaN        NaN      NaN
#         2011-08-16      M       1942   72             NaN        NaN      NaN
#         2011-11-19      M       1942   72             NaN        NaN      NaN
# 9581803 2011-03-16      M       1936   78             NaN  160.00269      124
#         2011-11-01      M       1936   78             NaN        NaN      NaN
# 9581807 2010-10-29      M       1944   70             NaN  270.00454      160
#         2010-11-10      M       1944   70             NaN        NaN      NaN
#         2010-11-23      M       1944   70             NaN        NaN      NaN
#         2011-03-08      M       1944   70             NaN  274.00373      140
#         2011-03-30      M       1944   70             NaN  276.00552      172
#         2011-04-18      M       1944   70             NaN        NaN      NaN
#         2011-06-07      M       1944   70             NaN        NaN      NaN
#         2011-08-05      M       1944   70             NaN        NaN      NaN
# 9581811 2011-04-15      M       1935   79             NaN        NaN      NaN
# 9581815 2012-03-01      M       1989   25             NaN        NaN      NaN
# 9581824 2012-03-01      M       1972   42             NaN        NaN      NaN
#
#                     FND_BPD  FND_HTIN  LR_AST  LR_MICROCR    ...      \
# pid     timestamp                                            ...
# 8545332 2006-08-11       70       NaN     NaN         NaN    ...
#         2006-11-02       70       NaN      25         NaN    ...
#         2007-06-05       70     64.00      29         NaN    ...
#         2010-02-09       69     64.00      41         NaN    ...
#         2010-08-17       78     64.00     NaN         NaN    ...
#         2011-04-13       65     64.00      29         NaN    ...
# 8545333 2007-05-31       70       NaN     NaN         NaN    ...
#         2010-06-10      NaN       NaN      21         NaN    ...
#         2010-06-10      NaN       NaN      21         NaN    ...
# 8545336 2010-11-18       82     62.50      21         NaN    ...
#         2011-09-01       41     62.50      22         NaN    ...
# 8545337 2010-10-29       74     62.00      25         NaN    ...
# 8545338 2007-10-11       80     67.00     NaN         NaN    ...
# 8545339 2010-05-24       75     66.50      16         NaN    ...
#         2010-05-24       75     66.50      16         NaN    ...
# 8545340 2007-04-19       80     62.75      16         NaN    ...
#         2007-10-01       80     62.75     NaN         NaN    ...
#         2007-10-09      NaN       NaN     NaN         NaN    ...
#         2008-12-18      NaN     62.75     NaN         NaN    ...
# 8545341 2006-12-06       78       NaN      26         NaN    ...
#         2007-03-26       70       NaN      33         NaN    ...
# 8545342 2007-02-20       56     62.00     NaN         NaN    ...
#         2007-07-19       64     62.00     NaN         NaN    ...
# 8545344 2007-11-26       78     72.00      19         NaN    ...
# 8545345 2009-06-25       71     69.00      26         NaN    ...
# 8545346 2009-01-15       89     65.00      27         NaN    ...
# 8545347 2010-10-29       70     63.50      24         NaN    ...
#         2010-10-29       70     63.50      24         NaN    ...
# 8545348 2006-08-10       90       NaN      45         NaN    ...
#         2009-05-04       66     64.00      21         NaN    ...
# ...                     ...       ...     ...         ...    ...
# 9581790 2011-05-06       64     62.00      27         NaN    ...
# 9581791 2011-08-29      NaN       NaN      13         NaN    ...
# 9581793 2011-09-02      NaN       NaN     NaN         NaN    ...
#         2011-09-02      NaN       NaN     NaN         NaN    ...
#         2011-11-08      NaN       NaN     NaN         NaN    ...
#         2012-02-15      NaN       NaN     NaN         NaN    ...
#         2012-03-01      NaN       NaN     NaN         NaN    ...
# 9581799 2011-06-24      NaN       NaN     NaN         NaN    ...
# 9581800 2011-01-06      NaN       NaN      18         NaN    ...
#         2011-03-08      NaN       NaN      20         NaN    ...
#         2011-08-08      NaN       NaN      18         NaN    ...
#         2011-10-18      NaN       NaN      24         NaN    ...
#         2012-01-24      NaN       NaN      22         NaN    ...
# 9581801 2011-03-30      NaN       NaN      16         NaN    ...
#         2011-07-20      NaN       NaN      27         NaN    ...
#         2011-08-16      NaN       NaN      18       531.2    ...
#         2011-11-19      NaN       NaN      21         NaN    ...
# 9581803 2011-03-16       80     66.00      28         NaN    ...
#         2011-11-01      NaN       NaN      23         NaN    ...
# 9581807 2010-10-29       80     67.50      16      5360.1    ...
#         2010-11-10      NaN       NaN     NaN         NaN    ...
#         2010-11-23      NaN       NaN     NaN         NaN    ...
#         2011-03-08       70       NaN     874         NaN    ...
#         2011-03-30       78     67.50      20         NaN    ...
#         2011-04-18      NaN       NaN     NaN         NaN    ...
#         2011-06-07      NaN       NaN      19         NaN    ...
#         2011-08-05      NaN       NaN     NaN         NaN    ...
# 9581811 2011-04-15      NaN       NaN      24         NaN    ...
# 9581815 2012-03-01      NaN       NaN     NaN         NaN    ...
# 9581824 2012-03-01      NaN       NaN     NaN         NaN    ...
#
#                     LR_GLUCNONFAST  LR_GLUCFAST  LR_LDL  LR_GFR  LR_VITD 25  \
# pid     timestamp
# 8545332 2006-08-11             107          NaN     100     NaN         NaN
#         2006-11-02             121          NaN     NaN     NaN         NaN
#         2007-06-05             117          NaN     127     NaN         NaN
#         2010-02-09             111          NaN     106     NaN         NaN
#         2010-08-17             103          NaN     NaN     NaN         NaN
#         2011-04-13             109          NaN     141   51.00         NaN
# 8545333 2007-05-31              92          NaN     NaN     NaN         NaN
#         2010-06-10             107          NaN     154     NaN         NaN
#         2010-06-10             107          NaN     154     NaN         NaN
# 8545336 2010-11-18              86          NaN      75     NaN         NaN
#         2011-09-01              81          NaN     NaN   46.00         NaN
# 8545337 2010-10-29              92          NaN      79     NaN         NaN
# 8545338 2007-10-11              87          NaN     NaN     NaN         NaN
# 8545339 2010-05-24              94          NaN     136     NaN         NaN
#         2010-05-24              94          NaN     136     NaN         NaN
# 8545340 2007-04-19              90          NaN      61     NaN         NaN
#         2007-10-01             126          NaN     NaN     NaN         NaN
#         2007-10-09              93          NaN     NaN     NaN         NaN
#         2008-12-18              89          NaN     NaN     NaN         NaN
# 8545341 2006-12-06             103          NaN     NaN     NaN         NaN
#         2007-03-26             101          NaN      73     NaN         NaN
# 8545342 2007-02-20              79          NaN      88     NaN         NaN
#         2007-07-19             NaN          NaN     NaN     NaN         NaN
# 8545344 2007-11-26              91          NaN     NaN     NaN         NaN
# 8545345 2009-06-25              77          NaN      66     NaN         NaN
# 8545346 2009-01-15              94          NaN     NaN     NaN         NaN
# 8545347 2010-10-29              80          NaN     NaN     NaN         NaN
#         2010-10-29              80          NaN     NaN     NaN         NaN
# 8545348 2006-08-10             101          NaN     NaN     NaN         NaN
#         2009-05-04              95          NaN     120     NaN         NaN
# ...                            ...          ...     ...     ...         ...
# 9581790 2011-05-06              80          NaN     100   40.00         NaN
# 9581791 2011-08-29             117          NaN     NaN   48.00         NaN
# 9581793 2011-09-02              97          NaN     NaN   45.48         NaN
#         2011-09-02              97          NaN     NaN   45.48         NaN
#         2011-11-08              93          NaN     NaN   36.83         NaN
#         2012-02-15              93          NaN     NaN   33.00         NaN
#         2012-03-01             115          NaN     NaN   38.00         NaN
# 9581799 2011-06-24             NaN          NaN     NaN   29.00         NaN
# 9581800 2011-01-06             108          NaN      95   55.00         NaN
#         2011-03-08             104          NaN      82   51.00         NaN
#         2011-08-08              97          NaN     NaN   48.00         NaN
#         2011-10-18             101          NaN      85   52.00         NaN
#         2012-01-24             104          NaN      81   50.00         NaN
# 9581801 2011-03-30             102          NaN     108   53.00         NaN
#         2011-07-20              96          NaN      88   46.00         NaN
#         2011-08-16              98          NaN     NaN   45.00         NaN
#         2011-11-19             116          NaN     100   46.00         NaN
# 9581803 2011-03-16              88          NaN      47   59.00         NaN
#         2011-11-01              99          NaN      54   54.00         NaN
# 9581807 2010-10-29             164          NaN     124   31.00         NaN
#         2010-11-10             163          NaN     NaN   27.00         NaN
#         2010-11-23             166          NaN     NaN   29.00         NaN
#         2011-03-08             112          NaN     NaN   18.00         NaN
#         2011-03-30             107          NaN     173   31.00         NaN
#         2011-04-18             105          NaN     NaN   26.00         NaN
#         2011-06-07             112          NaN     123   25.00         NaN
#         2011-08-05             106          NaN     107   24.00         NaN
# 9581811 2011-04-15             104          NaN      77   59.00          24
# 9581815 2012-03-01             NaN          NaN     NaN     NaN         NaN
# 9581824 2012-03-01             NaN          NaN     NaN     NaN         NaN
#
#                     LR_ALT  LR_VITD 1_25  LR_PHOS  LR_GFR_AFRAMER        gfr
# pid     timestamp
# 8545332 2006-08-11     NaN           NaN      NaN             NaN  46.662023
#         2006-11-02      21           NaN      NaN             NaN  46.662023
#         2007-06-05      18           NaN      NaN             NaN  52.087166
#         2010-02-09      30           NaN      NaN             NaN  49.235491
#         2010-08-17     NaN           NaN      NaN             NaN  45.235376
#         2011-04-13      20           NaN      NaN           59.00  52.694794
# 8545333 2007-05-31     NaN           NaN      NaN             NaN  48.687812
#         2010-06-10      21           NaN      NaN             NaN  52.525870
#         2010-06-10      21           NaN      NaN             NaN  52.525870
# 8545336 2010-11-18      14           NaN      NaN             NaN  43.858349
#         2011-09-01      13           NaN      NaN           53.00  46.605380
# 8545337 2010-10-29      26           NaN      NaN             NaN  49.782219
# 8545338 2007-10-11     NaN           NaN      NaN             NaN  44.946862
# 8545339 2010-05-24      22           NaN      NaN             NaN  40.733527
#         2010-05-24      22           NaN      NaN             NaN  40.733527
# 8545340 2007-04-19      17           NaN      NaN             NaN  52.325329
#         2007-10-01     NaN           NaN      NaN             NaN  46.875381
#         2007-10-09     NaN           NaN      NaN             NaN  52.325329
#         2008-12-18     NaN           NaN      NaN             NaN  39.354252
# 8545341 2006-12-06      22           NaN      NaN             NaN  48.963150
#         2007-03-26      34           NaN      NaN             NaN  44.285479
# 8545342 2007-02-20     NaN           NaN      NaN             NaN  47.435332
#         2007-07-19     NaN           NaN      NaN             NaN  52.950382
# 8545344 2007-11-26      16           NaN      NaN             NaN  45.824960
# 8545345 2009-06-25      23           NaN      NaN             NaN  48.476906
# 8545346 2009-01-15      22           NaN      NaN             NaN  48.976734
# 8545347 2010-10-29      18           NaN      NaN             NaN  46.882111
#         2010-10-29      18           NaN      NaN             NaN   0.459047
# 8545348 2006-08-10      42           NaN      NaN             NaN  54.348481
#         2009-05-04      16           NaN      NaN             NaN  46.253234
# ...                    ...           ...      ...             ...        ...
# 9581790 2011-05-06      15           NaN      NaN           46.00  45.096620
# 9581791 2011-08-29      12           NaN      NaN           56.00  52.808746
# 9581793 2011-09-02     NaN           NaN      3.5           55.03  47.982772
#         2011-09-02     NaN           NaN      3.5           55.03  47.982772
#         2011-11-08     NaN           NaN      NaN           44.56  38.878560
#         2012-02-15     NaN           NaN      3.7           38.00  36.088184
#         2012-03-01     NaN           NaN      NaN           44.00  41.249352
# 9581799 2011-06-24     NaN           NaN      NaN           34.00  33.297182
# 9581800 2011-01-06      13           NaN      NaN             NaN  58.294589
#         2011-03-08      13           NaN      NaN           59.00  53.865890
#         2011-08-08      12           NaN      NaN           56.00  51.667671
#         2011-10-18      14           NaN      NaN           60.00  55.270443
#         2012-01-24      14           NaN      NaN           58.00  53.412414
# 9581801 2011-03-30       9           NaN      NaN           62.00  54.748289
#         2011-07-20      10           NaN      NaN           54.00  48.153399
#         2011-08-16      10           NaN      NaN           52.00  46.731386
#         2011-11-19      11           NaN      NaN           53.00  48.153399
# 9581803 2011-03-16      36           NaN      NaN           68.00  61.642951
#         2011-11-01      25           NaN      NaN           62.00  57.252864
# 9581807 2010-10-29      11           NaN      NaN           38.00  32.988795
#         2010-11-10     NaN           NaN      NaN           32.00  27.916462
#         2010-11-23     NaN           NaN      NaN           35.00  30.641986
#         2011-03-08     526           NaN      NaN           21.00  19.591036
#         2011-03-30      24           NaN      4.3           36.00  32.633267
#         2011-04-18     NaN           NaN      NaN           30.00  27.655770
#         2011-06-07      25           NaN      NaN           29.00  26.066265
#         2011-08-05     NaN           NaN      NaN           28.00  25.836778
# 9581811 2011-04-15      16           NaN      NaN           69.00  62.677758
# 9581815 2012-03-01     NaN           NaN      NaN             NaN   0.480012
# 9581824 2012-03-01     NaN           NaN      NaN             NaN   0.369152
#
# [466108 rows x 25 columns]

# %% [markdown]
# ## Visualize how much lab-test/findings data <br>we really have corresponding to eGFR data

# %%
# How many values are NaNs
how_much_data_missing = []
for col_name in final_col_names:
    total_rowcount = len(combined_df[col_name].values)
    nan_rowcount = len([x for x in combined_df[col_name].values if math.isnan(x)])
    print (str(nan_rowcount*100/total_rowcount)+ "% of the values in " + col_name + ' are NaN')
    how_much_data_missing.append(nan_rowcount*100/total_rowcount)
# Out:
# 55% of the values in FND_WTLB are NaN
# 52% of the values in FND_BPS are NaN
# 52% of the values in FND_BPD are NaN
# 71% of the values in FND_HTIN are NaN
# 31% of the values in LR_AST are NaN
# 91% of the values in LR_MICROCR are NaN
# 42% of the values in LR_HDL are NaN
# 42% of the values in LR_TRIG are NaN
# 67% of the values in LR_A1C are NaN
# 0% of the values in LR_CR are NaN
# 99% of the values in LR_PTH are NaN
# 15% of the values in LR_GLUCNONFAST are NaN
# 88% of the values in LR_GLUCFAST are NaN
# 43% of the values in LR_LDL are NaN
# 51% of the values in LR_GFR are NaN
# 95% of the values in LR_VITD 25 are NaN
# 34% of the values in LR_ALT are NaN
# 99% of the values in LR_VITD 1_25 are NaN
# 98% of the values in LR_PHOS are NaN
# 81% of the values in LR_GFR_AFRAMER are NaN

# %%
threshold = 85

figure = plt.figure()
figure.set_size_inches(15.5, 5.5)
xaxisvals = [i for i,val in enumerate(final_col_names)]
plt.plot(xaxisvals, how_much_data_missing, linewidth=2.5, c='g', marker='o')
plt.xticks(xaxisvals, final_col_names, rotation=90)
plt.xlabel("Test name", fontsize=14)
plt.ylabel("% of data missing", fontsize=14)
plt.axhline(y=threshold, c="red",linewidth=2.5,zorder=0)
plt.grid()
plt.show()

# %% [markdown]
# ## Write the resultant DF to a CSV file

# %%
output_file_path = 'combined_df.csv'
combined_df.to_csv(output_file_path, sep='\t')

# %%
# Read intermediate temporary file
combined_df = pd.read_csv('~/code/independent/datasets/combined_df.csv', delimiter='\t', index_col=('pid','timestamp'))

# %% [markdown]
# ## Remove columns from the DF for which too much data is missing
#
# #### We don't want to use columns for which too much data is missing. Columns for <br>which the missing data crosses a configured threshold (80% as a heuristic) will be dropped

# %%
cols_to_drop = [i for i, val in enumerate(how_much_data_missing) if val > threshold]
# Add offset
cols_to_drop = np.add(cols_to_drop, 4)
print 'Dropping these columns from the DF:\n', combined_df.columns[cols_to_drop].tolist()
combined_df.drop(combined_df.columns[cols_to_drop], axis=1, inplace=True)
print '\nColumns dropped. There are now', combined_df.shape[1], 'columns in the DF'
# Out:
# Dropping these columns from the DF:
# ['LR_MICROCR', 'LR_PTH', 'LR_GLUCFAST', 'LR_VITD 25', 'LR_VITD 1_25', 'LR_PHOS']
#
# Columns dropped. There are now 19 columns in the DF

# %%
# After dropping columns with high amounts of missing data
combined_df
# Out:
#                    gender  birthyear  age   smoker_status   FND_WTLB  FND_BPS  \
# pid     timestamp
# 8545332 2006-08-11      F       1924   90  SOC_PastSmoker  152.50000      120
#         2006-11-02      F       1924   90  SOC_PastSmoker  156.00000      118
#         2007-06-05      F       1924   90  SOC_PastSmoker  157.00000      150
#         2010-02-09      F       1924   90  SOC_PastSmoker  163.00000      164
#         2010-08-17      F       1924   90  SOC_PastSmoker  162.00000      135
#         2011-04-13      F       1924   90  SOC_PastSmoker  163.00000      146
# 8545333 2007-05-31      F       1941   73   SOC_NonSmoker  147.00000      130
#         2010-06-10      F       1941   73   SOC_NonSmoker        NaN      NaN
#         2010-06-10      F       1941   73   SOC_NonSmoker        NaN      NaN
# 8545336 2010-11-18      F       1928   86   SOC_NonSmoker  121.00000      147
#         2011-09-01      F       1928   86   SOC_NonSmoker  113.00000      115
# 8545337 2010-10-29      F       1924   90  SOC_PastSmoker        NaN      120
# 8545338 2007-10-11      F       1948   66   SOC_NonSmoker  141.00000      140
# 8545339 2010-05-24      F       1946   68   SOC_NonSmoker  270.00000      155
#         2010-05-24      F       1946   68   SOC_NonSmoker  270.00000      155
# 8545340 2007-04-19      F       1926   88   SOC_NonSmoker  141.00000      140
#         2007-10-01      F       1926   88   SOC_NonSmoker  248.00000      140
#         2007-10-09      F       1926   88   SOC_NonSmoker        NaN      NaN
#         2008-12-18      F       1926   88   SOC_NonSmoker  150.00000      NaN
# 8545341 2006-12-06      F       1943   71             NaN  183.00000      132
#         2007-03-26      F       1943   71             NaN  189.00000      118
# 8545342 2007-02-20      F       1931   83  SOC_PastSmoker  128.00000      106
#         2007-07-19      F       1931   83  SOC_PastSmoker  128.00000      112
# 8545344 2007-11-26      F       1954   60      SOC_Smoker  194.00000      128
# 8545345 2009-06-25      F       1950   64  SOC_PastSmoker  295.00000      106
# 8545346 2009-01-15      F       1950   64   SOC_NonSmoker  128.00000      139
# 8545347 2010-10-29      F       1955   59   SOC_NonSmoker  176.00000      123
#         2010-10-29      F       1955   59   SOC_NonSmoker  176.00000      123
# 8545348 2006-08-10      F       1941   73   SOC_NonSmoker  197.00000      180
#         2009-05-04      F       1941   73   SOC_NonSmoker  182.00000      137
# ...                   ...        ...  ...             ...        ...      ...
# 9581790 2011-05-06      M       1925   89             NaN  107.00136      120
# 9581791 2011-08-29      M       1928   86             NaN        NaN      NaN
# 9581793 2011-09-02      M       1935   79  SOC_PastSmoker        NaN      NaN
#         2011-09-02      M       1935   79  SOC_PastSmoker        NaN      NaN
#         2011-11-08      M       1935   79  SOC_PastSmoker        NaN      NaN
#         2012-02-15      M       1935   79  SOC_PastSmoker        NaN      NaN
#         2012-03-01      M       1935   79  SOC_PastSmoker        NaN      NaN
# 9581799 2011-06-24      M       1926   88             NaN        NaN      NaN
# 9581800 2011-01-06      M       1936   78             NaN        NaN      NaN
#         2011-03-08      M       1936   78             NaN        NaN      NaN
#         2011-08-08      M       1936   78             NaN        NaN      NaN
#         2011-10-18      M       1936   78             NaN        NaN      NaN
#         2012-01-24      M       1936   78             NaN        NaN      NaN
# 9581801 2011-03-30      M       1942   72             NaN        NaN      NaN
#         2011-07-20      M       1942   72             NaN        NaN      NaN
#         2011-08-16      M       1942   72             NaN        NaN      NaN
#         2011-11-19      M       1942   72             NaN        NaN      NaN
# 9581803 2011-03-16      M       1936   78             NaN  160.00269      124
#         2011-11-01      M       1936   78             NaN        NaN      NaN
# 9581807 2010-10-29      M       1944   70             NaN  270.00454      160
#         2010-11-10      M       1944   70             NaN        NaN      NaN
#         2010-11-23      M       1944   70             NaN        NaN      NaN
#         2011-03-08      M       1944   70             NaN  274.00373      140
#         2011-03-30      M       1944   70             NaN  276.00552      172
#         2011-04-18      M       1944   70             NaN        NaN      NaN
#         2011-06-07      M       1944   70             NaN        NaN      NaN
#         2011-08-05      M       1944   70             NaN        NaN      NaN
# 9581811 2011-04-15      M       1935   79             NaN        NaN      NaN
# 9581815 2012-03-01      M       1989   25             NaN        NaN      NaN
# 9581824 2012-03-01      M       1972   42             NaN        NaN      NaN
#
#                     FND_BPD  FND_HTIN  LR_AST  LR_HDL  LR_TRIG  LR_A1C  \
# pid     timestamp
# 8545332 2006-08-11       70       NaN     NaN      46      188     NaN
#         2006-11-02       70       NaN      25     NaN      NaN     NaN
#         2007-06-05       70     64.00      29      43      163     NaN
#         2010-02-09       69     64.00      41      42      227     NaN
#         2010-08-17       78     64.00     NaN     NaN      NaN     NaN
#         2011-04-13       65     64.00      29      19      220     NaN
# 8545333 2007-05-31       70       NaN     NaN     NaN      NaN     NaN
#         2010-06-10      NaN       NaN      21      43      169     NaN
#         2010-06-10      NaN       NaN      21      43      169     NaN
# 8545336 2010-11-18       82     62.50      21      79      337     NaN
#         2011-09-01       41     62.50      22     NaN      NaN     NaN
# 8545337 2010-10-29       74     62.00      25      61      104     NaN
# 8545338 2007-10-11       80     67.00     NaN     NaN      NaN     NaN
# 8545339 2010-05-24       75     66.50      16      42      231     NaN
#         2010-05-24       75     66.50      16      42      231     NaN
# 8545340 2007-04-19       80     62.75      16      40      163     NaN
#         2007-10-01       80     62.75     NaN     NaN      NaN     NaN
#         2007-10-09      NaN       NaN     NaN     NaN      NaN     NaN
#         2008-12-18      NaN     62.75     NaN     NaN      NaN     NaN
# 8545341 2006-12-06       78       NaN      26     NaN      NaN     NaN
#         2007-03-26       70       NaN      33      55      288     NaN
# 8545342 2007-02-20       56     62.00     NaN      76      169     NaN
#         2007-07-19       64     62.00     NaN     NaN      NaN     NaN
# 8545344 2007-11-26       78     72.00      19     NaN      NaN     NaN
# 8545345 2009-06-25       71     69.00      26      60      201     6.3
# 8545346 2009-01-15       89     65.00      27     NaN      NaN     NaN
# 8545347 2010-10-29       70     63.50      24     NaN      NaN     NaN
#         2010-10-29       70     63.50      24     NaN      NaN     NaN
# 8545348 2006-08-10       90       NaN      45     NaN      NaN     NaN
#         2009-05-04       66     64.00      21      72      150     NaN
# ...                     ...       ...     ...     ...      ...     ...
# 9581790 2011-05-06       64     62.00      27      74       58     NaN
# 9581791 2011-08-29      NaN       NaN      13     NaN      NaN     NaN
# 9581793 2011-09-02      NaN       NaN     NaN     NaN      NaN     NaN
#         2011-09-02      NaN       NaN     NaN     NaN      NaN     NaN
#         2011-11-08      NaN       NaN     NaN     NaN      NaN     NaN
#         2012-02-15      NaN       NaN     NaN     NaN      NaN     NaN
#         2012-03-01      NaN       NaN     NaN     NaN      NaN     NaN
# 9581799 2011-06-24      NaN       NaN     NaN     NaN      NaN     NaN
# 9581800 2011-01-06      NaN       NaN      18      53       72     6.6
#         2011-03-08      NaN       NaN      20      51       75     6.3
#         2011-08-08      NaN       NaN      18     NaN      NaN     6.3
#         2011-10-18      NaN       NaN      24      59       81     6.5
#         2012-01-24      NaN       NaN      22      59       65     6.6
# 9581801 2011-03-30      NaN       NaN      16      59      195     NaN
#         2011-07-20      NaN       NaN      27      59      285     5.4
#         2011-08-16      NaN       NaN      18     NaN      NaN     NaN
#         2011-11-19      NaN       NaN      21      68      272     5.4
# 9581803 2011-03-16       80     66.00      28      46       57     NaN
#         2011-11-01      NaN       NaN      23      50       88     NaN
# 9581807 2010-10-29       80     67.50      16      40      302     7.7
#         2010-11-10      NaN       NaN     NaN     NaN      NaN     NaN
#         2010-11-23      NaN       NaN     NaN     NaN      NaN     NaN
#         2011-03-08       70       NaN     874     NaN      NaN     7.0
#         2011-03-30       78     67.50      20      35      343     NaN
#         2011-04-18      NaN       NaN     NaN     NaN      NaN     NaN
#         2011-06-07      NaN       NaN      19      28      322     6.0
#         2011-08-05      NaN       NaN     NaN      30      381     NaN
# 9581811 2011-04-15      NaN       NaN      24      64       83     NaN
# 9581815 2012-03-01      NaN       NaN     NaN     NaN      NaN     NaN
# 9581824 2012-03-01      NaN       NaN     NaN     NaN      NaN     NaN
#
#                      LR_CR  LR_GLUCNONFAST  LR_LDL  LR_GFR  LR_ALT  \
# pid     timestamp
# 8545332 2006-08-11    1.10             107     100     NaN     NaN
#         2006-11-02    1.10             121     NaN     NaN      21
#         2007-06-05    1.00             117     127     NaN      18
#         2010-02-09    1.05             111     106     NaN      30
#         2010-08-17    1.13             103     NaN     NaN     NaN
#         2011-04-13    0.99             109     141   51.00      20
# 8545333 2007-05-31    1.10              92     NaN     NaN     NaN
#         2010-06-10    1.03             107     154     NaN      21
#         2010-06-10    1.03             107     154     NaN      21
# 8545336 2010-11-18    1.17              86      75     NaN      14
#         2011-09-01    1.11              81     NaN   46.00      13
# 8545337 2010-10-29    1.04              92      79     NaN      26
# 8545338 2007-10-11    1.20              87     NaN     NaN     NaN
# 8545339 2010-05-24    1.30              94     136     NaN      22
#         2010-05-24    1.30              94     136     NaN      22
# 8545340 2007-04-19    1.00              90      61     NaN      17
#         2007-10-01    1.10             126     NaN     NaN     NaN
#         2007-10-09    1.00              93     NaN     NaN     NaN
#         2008-12-18    1.28              89     NaN     NaN     NaN
# 8545341 2006-12-06    1.10             103     NaN     NaN      22
#         2007-03-26    1.20             101      73     NaN      34
# 8545342 2007-02-20    1.10              79      88     NaN     NaN
#         2007-07-19    1.00             NaN     NaN     NaN     NaN
# 8545344 2007-11-26    1.20              91     NaN     NaN      16
# 8545345 2009-06-25    1.13              77      66     NaN      23
# 8545346 2009-01-15    1.12              94     NaN     NaN      22
# 8545347 2010-10-29    1.18              80     NaN     NaN      18
#         2010-10-29    1.18              80     NaN     NaN      18
# 8545348 2006-08-10    1.00             101     NaN     NaN      42
#         2009-05-04    1.15              95     120     NaN      16
# ...                    ...             ...     ...     ...     ...
# 9581790 2011-05-06    1.55              80     100   40.00      15
# 9581791 2011-08-29    1.36             117     NaN   48.00      12
# 9581793 2011-09-02    1.50              97     NaN   45.48     NaN
#         2011-09-02    1.50              97     NaN   45.48     NaN
#         2011-11-08    1.80              93     NaN   36.83     NaN
#         2012-02-15    1.92              93     NaN   33.00     NaN
#         2012-03-01    1.71             115     NaN   38.00     NaN
# 9581799 2011-06-24    2.02             NaN     NaN   29.00     NaN
# 9581800 2011-01-06    1.27             108      95   55.00      13
#         2011-03-08    1.36             104      82   51.00      13
#         2011-08-08    1.41              97     NaN   48.00      12
#         2011-10-18    1.33             101      85   52.00      14
#         2012-01-24    1.37             104      81   50.00      14
# 9581801 2011-03-30    1.36             102     108   53.00       9
#         2011-07-20    1.52              96      88   46.00      10
#         2011-08-16    1.56              98     NaN   45.00      10
#         2011-11-19    1.52             116     100   46.00      11
# 9581803 2011-03-16    1.21              88      47   59.00      36
#         2011-11-01    1.29              99      54   54.00      25
# 9581807 2010-10-29    2.12             164     124   31.00      11
#         2010-11-10    2.45             163     NaN   27.00     NaN
#         2010-11-23    2.26             166     NaN   29.00     NaN
#         2011-03-08    3.33             112     NaN   18.00     526
#         2011-03-30    2.14             107     173   31.00      24
#         2011-04-18    2.47             105     NaN   26.00     NaN
#         2011-06-07    2.60             112     123   25.00      25
#         2011-08-05    2.62             106     107   24.00     NaN
# 9581811 2011-04-15    1.19             104      77   59.00      16
# 9581815 2012-03-01   99.30             NaN     NaN     NaN     NaN
# 9581824 2012-03-01  113.80             NaN     NaN     NaN     NaN
#
#                     LR_GFR_AFRAMER        gfr
# pid     timestamp
# 8545332 2006-08-11             NaN  46.662023
#         2006-11-02             NaN  46.662023
#         2007-06-05             NaN  52.087166
#         2010-02-09             NaN  49.235491
#         2010-08-17             NaN  45.235376
#         2011-04-13           59.00  52.694794
# 8545333 2007-05-31             NaN  48.687812
#         2010-06-10             NaN  52.525870
#         2010-06-10             NaN  52.525870
# 8545336 2010-11-18             NaN  43.858349
#         2011-09-01           53.00  46.605380
# 8545337 2010-10-29             NaN  49.782219
# 8545338 2007-10-11             NaN  44.946862
# 8545339 2010-05-24             NaN  40.733527
#         2010-05-24             NaN  40.733527
# 8545340 2007-04-19             NaN  52.325329
#         2007-10-01             NaN  46.875381
#         2007-10-09             NaN  52.325329
#         2008-12-18             NaN  39.354252
# 8545341 2006-12-06             NaN  48.963150
#         2007-03-26             NaN  44.285479
# 8545342 2007-02-20             NaN  47.435332
#         2007-07-19             NaN  52.950382
# 8545344 2007-11-26             NaN  45.824960
# 8545345 2009-06-25             NaN  48.476906
# 8545346 2009-01-15             NaN  48.976734
# 8545347 2010-10-29             NaN  46.882111
#         2010-10-29             NaN   0.459047
# 8545348 2006-08-10             NaN  54.348481
#         2009-05-04             NaN  46.253234
# ...                            ...        ...
# 9581790 2011-05-06           46.00  45.096620
# 9581791 2011-08-29           56.00  52.808746
# 9581793 2011-09-02           55.03  47.982772
#         2011-09-02           55.03  47.982772
#         2011-11-08           44.56  38.878560
#         2012-02-15           38.00  36.088184
#         2012-03-01           44.00  41.249352
# 9581799 2011-06-24           34.00  33.297182
# 9581800 2011-01-06             NaN  58.294589
#         2011-03-08           59.00  53.865890
#         2011-08-08           56.00  51.667671
#         2011-10-18           60.00  55.270443
#         2012-01-24           58.00  53.412414
# 9581801 2011-03-30           62.00  54.748289
#         2011-07-20           54.00  48.153399
#         2011-08-16           52.00  46.731386
#         2011-11-19           53.00  48.153399
# 9581803 2011-03-16           68.00  61.642951
#         2011-11-01           62.00  57.252864
# 9581807 2010-10-29           38.00  32.988795
#         2010-11-10           32.00  27.916462
#         2010-11-23           35.00  30.641986
#         2011-03-08           21.00  19.591036
#         2011-03-30           36.00  32.633267
#         2011-04-18           30.00  27.655770
#         2011-06-07           29.00  26.066265
#         2011-08-05           28.00  25.836778
# 9581811 2011-04-15           69.00  62.677758
# 9581815 2012-03-01             NaN   0.480012
# 9581824 2012-03-01             NaN   0.369152
#
# [466108 rows x 19 columns]

# %% [markdown]
# #### Write the DF (columns with highly missing data removed) to a CSV file

# %%
output_file_path = 'combined_df_removedcolumns.csv'
combined_df.to_csv(output_file_path, sep='\t')

# %%
# Read intermediate temporary file
combined_df = pd.read_csv('combined_df_removedcolumns.csv', delimiter='\t', index_col=('pid','timestamp'))

# %%
combined_df.shape
# Out:
# (466108, 19)

# %% [markdown]
# ## Identifying and removing blatant outliers

# %% [markdown]
# ### Weight outliers

# %%
outliers = []
weight_threshold = 1000
weights = combined_df.FND_WTLB.values

figure = plt.figure()
figure.set_size_inches(12.5, 3.5)
plt.plot(weights)
plt.xlabel('Patients')
plt.ylabel('Weight (in lb)')
plt.axhline(y=weight_threshold, c="red",linewidth=1,zorder=0)

weight_outliers = [i for i,val in enumerate(weights) if val > weight_threshold]
outliers.extend(weight_outliers)
print '# of patients with weights beyond', weight_threshold, 'lb:', len(weight_outliers)
# Out:
# # of patients with weights beyond 1000 lb: 94

# %% [markdown]
# ### Height outliers

# %%
# Tallest man ever was 8 feet, so 10 feet is a safe threshold
height_threshold = 120
heights = combined_df.FND_HTIN.values

figure = plt.figure()
figure.set_size_inches(12.5, 3.5)
plt.plot(heights)
plt.xlabel('Patients')
plt.ylabel('Height (in inches)')
plt.axhline(y=height_threshold, c="red",linewidth=1,zorder=0)

height_outliers = [i for i,val in enumerate(heights) if val > height_threshold]
outliers.extend(height_outliers)
print '# of patients with heights beyond', height_threshold, 'inches =', len(height_outliers)
# Out:
# # of patients with heights beyond 120 inches = 155

# %% [markdown]
# ### Blood pressure outliers (systolic)

# %%
bp_threshold = 200
values = combined_df.FND_BPS.values

figure = plt.figure()
figure.set_size_inches(12.5, 3.5)
plt.plot(values)
plt.xlabel('Patients')
plt.ylabel('Blood pressure (Systolic)')
plt.axhline(y=bp_threshold, c="red",linewidth=1,zorder=0)

bp_outliers = [i for i,val in enumerate(values) if val > bp_threshold]
print '# of patients with systolic blood pressure beyond', bp_threshold, 'is', len(bp_outliers)
print '# of patients with systolic blood pressure < 0 is', len([i for i,val in enumerate(values) if val < 0])
outliers.extend(bp_outliers)
outliers.extend([i for i,val in enumerate(values) if val < 0])
# Out:
# # of patients with systolic blood pressure beyond 200 is 456
# # of patients with systolic blood pressure < 0 is 1

# %% [markdown]
# ### Blood pressure outliers (diastolic)

# %%
bp_threshold = 200
values = combined_df.FND_BPD.values

figure = plt.figure()
figure.set_size_inches(12.5, 3.5)
plt.plot(values)
plt.xlabel('Patients')
plt.ylabel('Blood pressure (Diastolic)')
plt.axhline(y=bp_threshold, c="red",linewidth=1,zorder=0)

bp_outliers = [i for i,val in enumerate(values) if val > bp_threshold]
outliers.extend(bp_outliers)
print '# of patients with diastolic blood pressure beyond', bp_threshold, 'is', len(bp_outliers)
# Out:
# # of patients with diastolic blood pressure beyond 200 is 57

# %% [markdown]
# ### eGFR outliers

# %%
gfr_threshold = 200
values = combined_df.gfr.values

figure = plt.figure()
figure.set_size_inches(12.5, 3.5)
plt.plot(values)
plt.xlabel('Patients')
plt.ylabel('eGFR')
plt.axhline(y=gfr_threshold, c="red",linewidth=1.5,zorder=0)

gfr_outliers = [i for i,val in enumerate(values) if val > gfr_threshold]
outliers.extend(gfr_outliers)
print '# of patients with eGFR values beyond', gfr_threshold, 'inches =', len(gfr_outliers)
# Out:
# # of patients with eGFR values beyond 200 inches = 58

# %% [markdown]
# ### AST (Aspartate Aminotransferase) outliers
# #### Typically, the normal range for the AST test is 10 to 34 IU/L (international units per liter). Levels of AST greater than 10 times the normal limit usually indicate a viral hepatitis infection, that is over 340. So taking a threshold of 1000 should be safe since even in the most sever infection, AST test values should not cross that threshold

# %%
AST_threshold = 1000
values = combined_df.LR_AST.values

figure = plt.figure()
figure.set_size_inches(12.5, 3.5)
plt.plot(values)
plt.xlabel('Patients')
plt.ylabel('AST (Aspartate Aminotransferase)')
plt.axhline(y=AST_threshold, c="red",linewidth=1.5,zorder=0)

AST_outliers = [i for i,val in enumerate(values) if val > AST_threshold]
outliers.extend(AST_outliers)
print '# of patients with AST values beyond', AST_threshold, 'IU/L =', len(AST_outliers)
# Out:
# # of patients with AST values beyond 1000 IU/L = 13

# %% [markdown]
# ### Triglycerides outliers
# #### Normal triglycerides means there are less than 150 milligrams per deciliter (mg/dL). Borderline high triglycerides = 150 to 199 mg/dL. Very high triglycerides = 500 mg/dL or higher. The highest world record (http://www.guinnessworldrecords.com/world-records/highest-triglyceride-level/) for triglyceride reading was 3165 mg/dl, 21 times the normal level of 150 mg/dl

# %%
TRIG_threshold = 3165
values = combined_df.LR_TRIG.values

figure = plt.figure()
figure.set_size_inches(12.5, 3.5)
plt.plot(values)
plt.xlabel('Patients')
plt.ylabel('AST (Aspartate Aminotransferase)')
plt.axhline(y=TRIG_threshold, c="red",linewidth=1.5,zorder=0)

TRIG_outliers = [i for i,val in enumerate(values) if val > TRIG_threshold]
outliers.extend(TRIG_outliers)
print '\n# of patients with Triglycerides values beyond', TRIG_threshold, 'mg/dL =', len(TRIG_outliers)
# Out:
# # of patients with Triglycerides values beyond 3165 mg/dL = 44

# %% [markdown]
# ### Creatinine level outliers
# #### Normal creatinine levels range from 0.7 to 1.3 mg/dL in men and 0.6 to 1.1 mg/dL in women. Anything more then 2 is acute and 5 is chronic and needs urgent intervention. The highest ever recorded creatine level was 61.3 mg/dL, so taking 100 as a threshold is appropriate.

# %%
def plot_pdf(data, title):
    data.sort()
    
    figure = plt.figure()
    figure.set_size_inches(15.5, 3.5)
    pdf = stats.norm.pdf(data, np.mean(data), np.std(data))
    plt.plot(data, pdf, '-o', linewidth=3)
    plt.grid()
    plt.title(title)
    plt.xticks(range(0,3500,200))
    plt.show()
    
vals = [x for x in combined_df.LR_CR.values if not math.isnan(x)]
plot_pdf(vals, "Distribution of Creatinine levels in patients\n(The x-axis represents creatinine level)")

# %%
CR_threshold = 100
values = combined_df.LR_CR.values

figure = plt.figure()
figure.set_size_inches(12.5, 3.5)
plt.plot(values)
plt.xlabel('Patients')
plt.ylabel('Creatinine level')
plt.axhline(y=CR_threshold, c="red",linewidth=1.5,zorder=0)

CR_outliers = [i for i,val in enumerate(values) if val > CR_threshold]
outliers.extend(CR_outliers)
print '\n# of patients with Creatinine levels beyond', CR_threshold, 'mg/dL =', len(CR_outliers)
# Out:
# # of patients with Creatinine levels beyond 100 mg/dL = 2521

# %% [markdown]
# ### Blood glucose level outliers
# #### The normal blood sugar range is between 80-120 mg/dl, but the highest recorded glucose level was 2,656 mg/dl (http://www.guinnessworldrecords.com/world-records/highest-blood-sugar-level/)

# %%
GLUCNONFAST_threshold = 2656
values = combined_df.LR_GLUCNONFAST.values

figure = plt.figure()
figure.set_size_inches(12.5, 3.5)
plt.plot(values)
plt.xlabel('Patients')
plt.ylabel('Glucose level')
plt.axhline(y=GLUCNONFAST_threshold, c="red",linewidth=1.5,zorder=0)

GLUCNONFAST_outliers = [i for i,val in enumerate(values) if val > GLUCNONFAST_threshold]
outliers.extend(GLUCNONFAST_outliers)
print '\n# of patients with Glucose levels beyond', GLUCNONFAST_threshold, 'mg/dL =', len(GLUCNONFAST_outliers)
# Out:
# # of patients with Glucose levels beyond 2656 mg/dL = 1

# %% [markdown]
# ### ALT (Alanine aminotransferase) outliers

# %%
ALT_threshold = 1000
values = combined_df.LR_ALT.values

figure = plt.figure()
figure.set_size_inches(12.5, 3.5)
plt.plot(values)
plt.xlabel('Patients')
plt.ylabel('ALT level')
plt.axhline(y=ALT_threshold, c="red",linewidth=1.5,zorder=0)

ALT_outliers = [i for i,val in enumerate(values) if val > ALT_threshold]
outliers.extend(ALT_outliers)
print '\n# of patients with ALT levels beyond', ALT_threshold, '=', len(ALT_outliers)
# Out:
# # of patients with ALT levels beyond 1000 = 13

# %% [markdown]
# ## Remove the outliers

# %%
outliers = list(set(outliers))
combined_df.drop(combined_df.index[outliers], inplace=True)
print len(outliers), "outliers were removed."
# Out:
# 3403 outliers were removed.

# %% [markdown]
# ### Write the dataframe with removed outliers to CSV

# %%
output_file_path = 'combined_df_no_outliers.csv'
combined_df.to_csv(output_file_path, sep='\t')

# %%
# Read intermediate temporary file
combined_df = pd.read_csv('combined_df_no_outliers.csv', delimiter='\t', index_col=('pid','timestamp'))

# %% [markdown]
# ## Convert categorical features to numerical ones

# %%
def categorical_to_numeric(col_name, df):
    column_values = df[col_name].values
    unique_values = np.unique(column_values)
    unique_values = [x for x in unique_values if type(x) is str]
        
    dicto = {value: index for (index, value) in enumerate(unique_values)}
    df.replace({col_name: dicto}, inplace=True)

categorical_to_numeric('smoker_status', combined_df)
categorical_to_numeric('gender', combined_df)

# %% [markdown]
# # Normalize the data

# %%
for col in combined_df.columns[3:-1]:
    colvalues = combined_df[col].values
    maxval = np.nanmax(colvalues)
    normalized_values = np.divide(colvalues, maxval)
    combined_df[col] = normalized_values
    print "The", col, "column has been normalized."
# Out:
# The smoker_status column has been normalized.
# The FND_WTLB column has been normalized.
# The FND_BPS column has been normalized.
# The FND_BPD column has been normalized.
# The FND_HTIN column has been normalized.
# The LR_AST column has been normalized.
# The LR_HDL column has been normalized.
# The LR_TRIG column has been normalized.
# The LR_A1C column has been normalized.
# The LR_CR column has been normalized.
# The LR_GLUCNONFAST column has been normalized.
# The LR_LDL column has been normalized.
# The LR_GFR column has been normalized.
# The LR_ALT column has been normalized.
# The LR_GFR_AFRAMER column has been normalized.

# %%
# Display the normalized dataframe
combined_df
# Out:
#                     gender  birthyear  age  smoker_status  FND_WTLB  FND_BPS  \
# pid     timestamp
# 8545332 2006-08-11       0       1924   90            0.5  0.191439    0.600
#         2006-11-02       0       1924   90            0.5  0.195832    0.590
#         2007-06-05       0       1924   90            0.5  0.197088    0.750
#         2010-02-09       0       1924   90            0.5  0.204620    0.820
#         2010-08-17       0       1924   90            0.5  0.203364    0.675
#         2011-04-13       0       1924   90            0.5  0.204620    0.730
# 8545333 2007-05-31       0       1941   73            0.0  0.184534    0.650
#         2010-06-10       0       1941   73            0.0       NaN      NaN
#         2010-06-10       0       1941   73            0.0       NaN      NaN
# 8545336 2010-11-18       0       1928   86            0.0  0.151896    0.735
#         2011-09-01       0       1928   86            0.0  0.141853    0.575
# 8545337 2010-10-29       0       1924   90            0.5       NaN    0.600
# 8545338 2007-10-11       0       1948   66            0.0  0.177002    0.700
# 8545339 2010-05-24       0       1946   68            0.0  0.338940    0.775
#         2010-05-24       0       1946   68            0.0  0.338940    0.775
# 8545340 2007-04-19       0       1926   88            0.0  0.177002    0.700
#         2007-10-01       0       1926   88            0.0  0.311323    0.700
#         2007-10-09       0       1926   88            0.0       NaN      NaN
#         2008-12-18       0       1926   88            0.0  0.188300      NaN
# 8545341 2006-12-06       0       1943   71            NaN  0.229726    0.660
#         2007-03-26       0       1943   71            NaN  0.237258    0.590
# 8545342 2007-02-20       0       1931   83            0.5  0.160683    0.530
#         2007-07-19       0       1931   83            0.5  0.160683    0.560
# 8545344 2007-11-26       0       1954   60            1.0  0.243535    0.640
# 8545345 2009-06-25       0       1950   64            0.5  0.370324    0.530
# 8545346 2009-01-15       0       1950   64            0.0  0.160683    0.695
# 8545347 2010-10-29       0       1955   59            0.0  0.220939    0.615
#         2010-10-29       0       1955   59            0.0  0.220939    0.615
# 8545348 2006-08-10       0       1941   73            0.0  0.247301    0.900
#         2009-05-04       0       1941   73            0.0  0.228471    0.685
# ...                    ...        ...  ...            ...       ...      ...
# 9581789 2011-09-13       1       1929   85            NaN       NaN      NaN
# 9581790 2011-05-06       1       1925   89            NaN  0.134323    0.600
# 9581791 2011-08-29       1       1928   86            NaN       NaN      NaN
# 9581793 2011-09-02       1       1935   79            0.5       NaN      NaN
#         2011-09-02       1       1935   79            0.5       NaN      NaN
#         2011-11-08       1       1935   79            0.5       NaN      NaN
#         2012-02-15       1       1935   79            0.5       NaN      NaN
#         2012-03-01       1       1935   79            0.5       NaN      NaN
# 9581799 2011-06-24       1       1926   88            NaN       NaN      NaN
# 9581800 2011-01-06       1       1936   78            NaN       NaN      NaN
#         2011-03-08       1       1936   78            NaN       NaN      NaN
#         2011-08-08       1       1936   78            NaN       NaN      NaN
#         2011-10-18       1       1936   78            NaN       NaN      NaN
#         2012-01-24       1       1936   78            NaN       NaN      NaN
# 9581801 2011-03-30       1       1942   72            NaN       NaN      NaN
#         2011-07-20       1       1942   72            NaN       NaN      NaN
#         2011-08-16       1       1942   72            NaN       NaN      NaN
#         2011-11-19       1       1942   72            NaN       NaN      NaN
# 9581803 2011-03-16       1       1936   78            NaN  0.200857    0.620
#         2011-11-01       1       1936   78            NaN       NaN      NaN
# 9581807 2010-10-29       1       1944   70            NaN  0.338946    0.800
#         2010-11-10       1       1944   70            NaN       NaN      NaN
#         2010-11-23       1       1944   70            NaN       NaN      NaN
#         2011-03-08       1       1944   70            NaN  0.343967    0.700
#         2011-03-30       1       1944   70            NaN  0.346479    0.860
#         2011-04-18       1       1944   70            NaN       NaN      NaN
#         2011-06-07       1       1944   70            NaN       NaN      NaN
#         2011-08-05       1       1944   70            NaN       NaN      NaN
# 9581811 2011-04-15       1       1935   79            NaN       NaN      NaN
# 9581815 2012-03-01       1       1989   25            NaN       NaN      NaN
#
#                      FND_BPD  FND_HTIN    LR_AST    LR_HDL   LR_TRIG  \
# pid     timestamp
# 8545332 2006-08-11  0.368421       NaN       NaN  0.235897  0.061218
#         2006-11-02  0.368421       NaN  0.025536       NaN       NaN
#         2007-06-05  0.368421  0.533333  0.029622  0.220513  0.053077
#         2010-02-09  0.363158  0.533333  0.041879  0.215385  0.073917
#         2010-08-17  0.410526  0.533333       NaN       NaN       NaN
#         2011-04-13  0.342105  0.533333  0.029622  0.097436  0.071638
# 8545333 2007-05-31  0.368421       NaN       NaN       NaN       NaN
#         2010-06-10       NaN       NaN  0.021450  0.220513  0.055031
#         2010-06-10       NaN       NaN  0.021450  0.220513  0.055031
# 8545336 2010-11-18  0.431579  0.520833  0.021450  0.405128  0.109736
#         2011-09-01  0.215789  0.520833  0.022472       NaN       NaN
# 8545337 2010-10-29  0.389474  0.516667  0.025536  0.312821  0.033865
# 8545338 2007-10-11  0.421053  0.558333       NaN       NaN       NaN
# 8545339 2010-05-24  0.394737  0.554167  0.016343  0.215385  0.075220
#         2010-05-24  0.394737  0.554167  0.016343  0.215385  0.075220
# 8545340 2007-04-19  0.421053  0.522917  0.016343  0.205128  0.053077
#         2007-10-01  0.421053  0.522917       NaN       NaN       NaN
#         2007-10-09       NaN       NaN       NaN       NaN       NaN
#         2008-12-18       NaN  0.522917       NaN       NaN       NaN
# 8545341 2006-12-06  0.410526       NaN  0.026558       NaN       NaN
#         2007-03-26  0.368421       NaN  0.033708  0.282051  0.093781
# 8545342 2007-02-20  0.294737  0.516667       NaN  0.389744  0.055031
#         2007-07-19  0.336842  0.516667       NaN       NaN       NaN
# 8545344 2007-11-26  0.410526  0.600000  0.019408       NaN       NaN
# 8545345 2009-06-25  0.373684  0.575000  0.026558  0.307692  0.065451
# 8545346 2009-01-15  0.468421  0.541667  0.027579       NaN       NaN
# 8545347 2010-10-29  0.368421  0.529167  0.024515       NaN       NaN
#         2010-10-29  0.368421  0.529167  0.024515       NaN       NaN
# 8545348 2006-08-10  0.473684       NaN  0.045965       NaN       NaN
#         2009-05-04  0.347368  0.533333  0.021450  0.369231  0.048844
# ...                      ...       ...       ...       ...       ...
# 9581789 2011-09-13       NaN       NaN  0.018386  0.261538  0.042006
# 9581790 2011-05-06  0.336842  0.516667  0.027579  0.379487  0.018886
# 9581791 2011-08-29       NaN       NaN  0.013279       NaN       NaN
# 9581793 2011-09-02       NaN       NaN       NaN       NaN       NaN
#         2011-09-02       NaN       NaN       NaN       NaN       NaN
#         2011-11-08       NaN       NaN       NaN       NaN       NaN
#         2012-02-15       NaN       NaN       NaN       NaN       NaN
#         2012-03-01       NaN       NaN       NaN       NaN       NaN
# 9581799 2011-06-24       NaN       NaN       NaN       NaN       NaN
# 9581800 2011-01-06       NaN       NaN  0.018386  0.271795  0.023445
#         2011-03-08       NaN       NaN  0.020429  0.261538  0.024422
#         2011-08-08       NaN       NaN  0.018386       NaN       NaN
#         2011-10-18       NaN       NaN  0.024515  0.302564  0.026376
#         2012-01-24       NaN       NaN  0.022472  0.302564  0.021166
# 9581801 2011-03-30       NaN       NaN  0.016343  0.302564  0.063497
#         2011-07-20       NaN       NaN  0.027579  0.302564  0.092804
#         2011-08-16       NaN       NaN  0.018386       NaN       NaN
#         2011-11-19       NaN       NaN  0.021450  0.348718  0.088570
# 9581803 2011-03-16  0.421053  0.550000  0.028601  0.235897  0.018561
#         2011-11-01       NaN       NaN  0.023493  0.256410  0.028655
# 9581807 2010-10-29  0.421053  0.562500  0.016343  0.205128  0.098339
#         2010-11-10       NaN       NaN       NaN       NaN       NaN
#         2010-11-23       NaN       NaN       NaN       NaN       NaN
#         2011-03-08  0.368421       NaN  0.892748       NaN       NaN
#         2011-03-30  0.410526  0.562500  0.020429  0.179487  0.111690
#         2011-04-18       NaN       NaN       NaN       NaN       NaN
#         2011-06-07       NaN       NaN  0.019408  0.143590  0.104852
#         2011-08-05       NaN       NaN       NaN  0.153846  0.124064
# 9581811 2011-04-15       NaN       NaN  0.024515  0.328205  0.027027
# 9581815 2012-03-01       NaN       NaN       NaN       NaN       NaN
#
#                       LR_A1C   LR_CR  LR_GLUCNONFAST    LR_LDL    LR_GFR  \
# pid     timestamp
# 8545332 2006-08-11       NaN  0.0110        0.071333  0.121507       NaN
#         2006-11-02       NaN  0.0110        0.080667       NaN       NaN
#         2007-06-05       NaN  0.0100        0.078000  0.154313       NaN
#         2010-02-09       NaN  0.0105        0.074000  0.128797       NaN
#         2010-08-17       NaN  0.0113        0.068667       NaN       NaN
#         2011-04-13       NaN  0.0099        0.072667  0.171324  0.283333
# 8545333 2007-05-31       NaN  0.0110        0.061333       NaN       NaN
#         2010-06-10       NaN  0.0103        0.071333  0.187120       NaN
#         2010-06-10       NaN  0.0103        0.071333  0.187120       NaN
# 8545336 2010-11-18       NaN  0.0117        0.057333  0.091130       NaN
#         2011-09-01       NaN  0.0111        0.054000       NaN  0.255556
# 8545337 2010-10-29       NaN  0.0104        0.061333  0.095990       NaN
# 8545338 2007-10-11       NaN  0.0120        0.058000       NaN       NaN
# 8545339 2010-05-24       NaN  0.0130        0.062667  0.165249       NaN
#         2010-05-24       NaN  0.0130        0.062667  0.165249       NaN
# 8545340 2007-04-19       NaN  0.0100        0.060000  0.074119       NaN
#         2007-10-01       NaN  0.0110        0.084000       NaN       NaN
#         2007-10-09       NaN  0.0100        0.062000       NaN       NaN
#         2008-12-18       NaN  0.0128        0.059333       NaN       NaN
# 8545341 2006-12-06       NaN  0.0110        0.068667       NaN       NaN
#         2007-03-26       NaN  0.0120        0.067333  0.088700       NaN
# 8545342 2007-02-20       NaN  0.0110        0.052667  0.106926       NaN
#         2007-07-19       NaN  0.0100             NaN       NaN       NaN
# 8545344 2007-11-26       NaN  0.0120        0.060667       NaN       NaN
# 8545345 2009-06-25  0.064483  0.0113        0.051333  0.080194       NaN
# 8545346 2009-01-15       NaN  0.0112        0.062667       NaN       NaN
# 8545347 2010-10-29       NaN  0.0118        0.053333       NaN       NaN
#         2010-10-29       NaN  0.0118        0.053333       NaN       NaN
# 8545348 2006-08-10       NaN  0.0100        0.067333       NaN       NaN
#         2009-05-04       NaN  0.0115        0.063333  0.145808       NaN
# ...                      ...     ...             ...       ...       ...
# 9581789 2011-09-13       NaN  0.0133        0.057333  0.134872  0.272222
# 9581790 2011-05-06       NaN  0.0155        0.053333  0.121507  0.222222
# 9581791 2011-08-29       NaN  0.0136        0.078000       NaN  0.266667
# 9581793 2011-09-02       NaN  0.0150        0.064667       NaN  0.252667
#         2011-09-02       NaN  0.0150        0.064667       NaN  0.252667
#         2011-11-08       NaN  0.0180        0.062000       NaN  0.204611
#         2012-02-15       NaN  0.0192        0.062000       NaN  0.183333
#         2012-03-01       NaN  0.0171        0.076667       NaN  0.211111
# 9581799 2011-06-24       NaN  0.0202             NaN       NaN  0.161111
# 9581800 2011-01-06  0.067554  0.0127        0.072000  0.115431  0.305556
#         2011-03-08  0.064483  0.0136        0.069333  0.099635  0.283333
#         2011-08-08  0.064483  0.0141        0.064667       NaN  0.266667
#         2011-10-18  0.066530  0.0133        0.067333  0.103281  0.288889
#         2012-01-24  0.067554  0.0137        0.069333  0.098420  0.277778
# 9581801 2011-03-30       NaN  0.0136        0.068000  0.131227  0.294444
#         2011-07-20  0.055271  0.0152        0.064000  0.106926  0.255556
#         2011-08-16       NaN  0.0156        0.065333       NaN  0.250000
#         2011-11-19  0.055271  0.0152        0.077333  0.121507  0.255556
# 9581803 2011-03-16       NaN  0.0121        0.058667  0.057108  0.327778
#         2011-11-01       NaN  0.0129        0.066000  0.065614  0.300000
# 9581807 2010-10-29  0.078813  0.0212        0.109333  0.150668  0.172222
#         2010-11-10       NaN  0.0245        0.108667       NaN  0.150000
#         2010-11-23       NaN  0.0226        0.110667       NaN  0.161111
#         2011-03-08  0.071648  0.0333        0.074667       NaN  0.100000
#         2011-03-30       NaN  0.0214        0.071333  0.210207  0.172222
#         2011-04-18       NaN  0.0247        0.070000       NaN  0.144444
#         2011-06-07  0.061412  0.0260        0.074667  0.149453  0.138889
#         2011-08-05       NaN  0.0262        0.070667  0.130012  0.133333
# 9581811 2011-04-15       NaN  0.0119        0.069333  0.093560  0.327778
# 9581815 2012-03-01       NaN  0.9930             NaN       NaN       NaN
#
#                       LR_ALT  LR_GFR_AFRAMER        gfr
# pid     timestamp
# 8545332 2006-08-11       NaN             NaN  46.662023
#         2006-11-02  0.021084             NaN  46.662023
#         2007-06-05  0.018072             NaN  52.087166
#         2010-02-09  0.030120             NaN  49.235491
#         2010-08-17       NaN             NaN  45.235376
#         2011-04-13  0.020080        0.270642  52.694794
# 8545333 2007-05-31       NaN             NaN  48.687812
#         2010-06-10  0.021084             NaN  52.525870
#         2010-06-10  0.021084             NaN  52.525870
# 8545336 2010-11-18  0.014056             NaN  43.858349
#         2011-09-01  0.013052        0.243119  46.605380
# 8545337 2010-10-29  0.026104             NaN  49.782219
# 8545338 2007-10-11       NaN             NaN  44.946862
# 8545339 2010-05-24  0.022088             NaN  40.733527
#         2010-05-24  0.022088             NaN  40.733527
# 8545340 2007-04-19  0.017068             NaN  52.325329
#         2007-10-01       NaN             NaN  46.875381
#         2007-10-09       NaN             NaN  52.325329
#         2008-12-18       NaN             NaN  39.354252
# 8545341 2006-12-06  0.022088             NaN  48.963150
#         2007-03-26  0.034137             NaN  44.285479
# 8545342 2007-02-20       NaN             NaN  47.435332
#         2007-07-19       NaN             NaN  52.950382
# 8545344 2007-11-26  0.016064             NaN  45.824960
# 8545345 2009-06-25  0.023092             NaN  48.476906
# 8545346 2009-01-15  0.022088             NaN  48.976734
# 8545347 2010-10-29  0.018072             NaN  46.882111
#         2010-10-29  0.018072             NaN   0.459047
# 8545348 2006-08-10  0.042169             NaN  54.348481
#         2009-05-04  0.016064             NaN  46.253234
# ...                      ...             ...        ...
# 9581789 2011-09-13  0.014056        0.261468  54.314540
# 9581790 2011-05-06  0.015060        0.211009  45.096620
# 9581791 2011-08-29  0.012048        0.256881  52.808746
# 9581793 2011-09-02       NaN        0.252431  47.982772
#         2011-09-02       NaN        0.252431  47.982772
#         2011-11-08       NaN        0.204404  38.878560
#         2012-02-15       NaN        0.174312  36.088184
#         2012-03-01       NaN        0.201835  41.249352
# 9581799 2011-06-24       NaN        0.155963  33.297182
# 9581800 2011-01-06  0.013052             NaN  58.294589
#         2011-03-08  0.013052        0.270642  53.865890
#         2011-08-08  0.012048        0.256881  51.667671
#         2011-10-18  0.014056        0.275229  55.270443
#         2012-01-24  0.014056        0.266055  53.412414
# 9581801 2011-03-30  0.009036        0.284404  54.748289
#         2011-07-20  0.010040        0.247706  48.153399
#         2011-08-16  0.010040        0.238532  46.731386
#         2011-11-19  0.011044        0.243119  48.153399
# 9581803 2011-03-16  0.036145        0.311927  61.642951
#         2011-11-01  0.025100        0.284404  57.252864
# 9581807 2010-10-29  0.011044        0.174312  32.988795
#         2010-11-10       NaN        0.146789  27.916462
#         2010-11-23       NaN        0.160550  30.641986
#         2011-03-08  0.528112        0.096330  19.591036
#         2011-03-30  0.024096        0.165138  32.633267
#         2011-04-18       NaN        0.137615  27.655770
#         2011-06-07  0.025100        0.133028  26.066265
#         2011-08-05       NaN        0.128440  25.836778
# 9581811 2011-04-15  0.016064        0.316514  62.677758
# 9581815 2012-03-01       NaN             NaN   0.480012
#
# [462698 rows x 19 columns]

# %% [markdown]
# ### Write the normalized dataframe to CSV

# %%
output_file_path = 'combined_df_normalized.csv'
combined_df.to_csv(output_file_path, sep='\t')

# %%
# Read CSV with combined, filtered, and normalized data
combined_df = pd.read_csv('combined_df_normalized.csv', delimiter='\t')

# %% [markdown]
# ## Fill in interpolated feature values

# %% [markdown]
# #### Spline interpolations with order=2

# %%
current_method = 'spline'
interpolated_spline2 = combined_df.interpolate(method=current_method, order=2, limit_direction='both', limit=100000)
interpolated_spline2
# Out:
#             pid   timestamp  gender  birthyear  age  smoker_status  FND_WTLB  \
# 0       8545332  2006-08-11       0       1924   90       0.500000  0.191439
# 1       8545332  2006-11-02       0       1924   90       0.500000  0.195832
# 2       8545332  2007-06-05       0       1924   90       0.500000  0.197088
# 3       8545332  2010-02-09       0       1924   90       0.500000  0.204620
# 4       8545332  2010-08-17       0       1924   90       0.500000  0.203364
# 5       8545332  2011-04-13       0       1924   90       0.500000  0.204620
# 6       8545333  2007-05-31       0       1941   73       0.000000  0.184534
# 7       8545333  2010-06-10       0       1941   73       0.000000  0.221741
# 8       8545333  2010-06-10       0       1941   73       0.000000  0.221741
# 9       8545336  2010-11-18       0       1928   86       0.000000  0.151896
# 10      8545336  2011-09-01       0       1928   86       0.000000  0.141853
# 11      8545337  2010-10-29       0       1924   90       0.500000  0.221741
# 12      8545338  2007-10-11       0       1948   66       0.000000  0.177002
# 13      8545339  2010-05-24       0       1946   68       0.000000  0.338940
# 14      8545339  2010-05-24       0       1946   68       0.000000  0.338940
# 15      8545340  2007-04-19       0       1926   88       0.000000  0.177002
# 16      8545340  2007-10-01       0       1926   88       0.000000  0.311323
# 17      8545340  2007-10-09       0       1926   88       0.000000  0.221740
# 18      8545340  2008-12-18       0       1926   88       0.000000  0.188300
# 19      8545341  2006-12-06       0       1943   71       0.212857  0.229726
# 20      8545341  2007-03-26       0       1943   71       0.212857  0.237258
# 21      8545342  2007-02-20       0       1931   83       0.500000  0.160683
# 22      8545342  2007-07-19       0       1931   83       0.500000  0.160683
# 23      8545344  2007-11-26       0       1954   60       1.000000  0.243535
# 24      8545345  2009-06-25       0       1950   64       0.500000  0.370324
# 25      8545346  2009-01-15       0       1950   64       0.000000  0.160683
# 26      8545347  2010-10-29       0       1955   59       0.000000  0.220939
# 27      8545347  2010-10-29       0       1955   59       0.000000  0.220939
# 28      8545348  2006-08-10       0       1941   73       0.000000  0.247301
# 29      8545348  2009-05-04       0       1941   73       0.000000  0.228471
# ...         ...         ...     ...        ...  ...            ...       ...
# 462668  9581789  2011-09-13       1       1929   85       0.191974  0.283098
# 462669  9581790  2011-05-06       1       1925   89       0.191974  0.134323
# 462670  9581791  2011-08-29       1       1928   86       0.191974  0.283099
# 462671  9581793  2011-09-02       1       1935   79       0.500000  0.283099
# 462672  9581793  2011-09-02       1       1935   79       0.500000  0.283099
# 462673  9581793  2011-11-08       1       1935   79       0.500000  0.283100
# 462674  9581793  2012-02-15       1       1935   79       0.500000  0.283100
# 462675  9581793  2012-03-01       1       1935   79       0.500000  0.283100
# 462676  9581799  2011-06-24       1       1926   88       0.191974  0.283101
# 462677  9581800  2011-01-06       1       1936   78       0.191974  0.283101
# 462678  9581800  2011-03-08       1       1936   78       0.191974  0.283101
# 462679  9581800  2011-08-08       1       1936   78       0.191974  0.283102
# 462680  9581800  2011-10-18       1       1936   78       0.191974  0.283102
# 462681  9581800  2012-01-24       1       1936   78       0.191974  0.283102
# 462682  9581801  2011-03-30       1       1942   72       0.191974  0.283103
# 462683  9581801  2011-07-20       1       1942   72       0.191974  0.283103
# 462684  9581801  2011-08-16       1       1942   72       0.191974  0.283103
# 462685  9581801  2011-11-19       1       1942   72       0.191974  0.283104
# 462686  9581803  2011-03-16       1       1936   78       0.191974  0.200857
# 462687  9581803  2011-11-01       1       1936   78       0.191974  0.283104
# 462688  9581807  2010-10-29       1       1944   70       0.191974  0.338946
# 462689  9581807  2010-11-10       1       1944   70       0.191974  0.283105
# 462690  9581807  2010-11-23       1       1944   70       0.191974  0.283105
# 462691  9581807  2011-03-08       1       1944   70       0.191974  0.343967
# 462692  9581807  2011-03-30       1       1944   70       0.191974  0.346479
# 462693  9581807  2011-04-18       1       1944   70       0.191974  0.283106
# 462694  9581807  2011-06-07       1       1944   70       0.191974  0.283106
# 462695  9581807  2011-08-05       1       1944   70       0.191974  0.283107
# 462696  9581811  2011-04-15       1       1935   79       0.191974  0.283107
# 462697  9581815  2012-03-01       1       1989   25       0.191974  0.283107
#
#          FND_BPS   FND_BPD  FND_HTIN    ...        LR_HDL   LR_TRIG    LR_A1C  \
# 0       0.600000  0.368421  0.525670    ...      0.235897  0.061218  0.070799
# 1       0.590000  0.368421  0.525670    ...      0.281102  0.047917  0.070799
# 2       0.750000  0.368421  0.533333    ...      0.220513  0.053077  0.070799
# 3       0.820000  0.363158  0.533333    ...      0.215385  0.073917  0.070799
# 4       0.675000  0.410526  0.533333    ...      0.281102  0.047917  0.070799
# 5       0.730000  0.342105  0.533333    ...      0.097436  0.071638  0.070799
# 6       0.650000  0.368421  0.525669    ...      0.281102  0.047917  0.070799
# 7       0.658833  0.395937  0.525669    ...      0.220513  0.055031  0.070799
# 8       0.658833  0.395937  0.525669    ...      0.220513  0.055031  0.070799
# 9       0.735000  0.431579  0.520833    ...      0.405128  0.109736  0.070799
# 10      0.575000  0.215789  0.520833    ...      0.281102  0.047917  0.070799
# 11      0.600000  0.389474  0.516667    ...      0.312821  0.033865  0.070799
# 12      0.700000  0.421053  0.558333    ...      0.281102  0.047917  0.070799
# 13      0.775000  0.394737  0.554167    ...      0.215385  0.075220  0.070799
# 14      0.775000  0.394737  0.554167    ...      0.215385  0.075220  0.070799
# 15      0.700000  0.421053  0.522917    ...      0.205128  0.053077  0.070799
# 16      0.700000  0.421053  0.522917    ...      0.281102  0.047917  0.070799
# 17      0.658832  0.395937  0.525669    ...      0.281102  0.047917  0.070799
# 18      0.658832  0.395937  0.522917    ...      0.281102  0.047917  0.070799
# 19      0.660000  0.410526  0.525669    ...      0.281102  0.047917  0.070799
# 20      0.590000  0.368421  0.525669    ...      0.282051  0.093781  0.070799
# 21      0.530000  0.294737  0.516667    ...      0.389744  0.055031  0.070799
# 22      0.560000  0.336842  0.516667    ...      0.281102  0.047917  0.070799
# 23      0.640000  0.410526  0.600000    ...      0.281102  0.047917  0.070799
# 24      0.530000  0.373684  0.575000    ...      0.307692  0.065451  0.064483
# 25      0.695000  0.468421  0.541667    ...      0.281102  0.047917  0.070799
# 26      0.615000  0.368421  0.529167    ...      0.281102  0.047917  0.070799
# 27      0.615000  0.368421  0.529167    ...      0.281102  0.047917  0.070799
# 28      0.900000  0.473684  0.525669    ...      0.281102  0.047917  0.070799
# 29      0.685000  0.347368  0.533333    ...      0.369231  0.048844  0.070799
# ...          ...       ...       ...    ...           ...       ...       ...
# 462668  0.642659  0.402401  0.597811    ...      0.261538  0.042006  0.072317
# 462669  0.600000  0.336842  0.516667    ...      0.379487  0.018886  0.072317
# 462670  0.642659  0.402401  0.597812    ...      0.202141  0.053196  0.072317
# 462671  0.642659  0.402401  0.597812    ...      0.202141  0.053196  0.072317
# 462672  0.642659  0.402401  0.597812    ...      0.202140  0.053196  0.072317
# 462673  0.642659  0.402401  0.597813    ...      0.202140  0.053196  0.072317
# 462674  0.642659  0.402401  0.597813    ...      0.202140  0.053196  0.072317
# 462675  0.642659  0.402401  0.597813    ...      0.202139  0.053196  0.072317
# 462676  0.642659  0.402401  0.597814    ...      0.202139  0.053196  0.072317
# 462677  0.642659  0.402401  0.597814    ...      0.271795  0.023445  0.067554
# 462678  0.642659  0.402401  0.597814    ...      0.261538  0.024422  0.064483
# 462679  0.642659  0.402401  0.597815    ...      0.202138  0.053196  0.064483
# 462680  0.642659  0.402401  0.597815    ...      0.302564  0.026376  0.066530
# 462681  0.642659  0.402401  0.597815    ...      0.302564  0.021166  0.067554
# 462682  0.642659  0.402401  0.597816    ...      0.302564  0.063497  0.072317
# 462683  0.642659  0.402401  0.597816    ...      0.302564  0.092804  0.055271
# 462684  0.642659  0.402401  0.597817    ...      0.202136  0.053196  0.072317
# 462685  0.642659  0.402402  0.597817    ...      0.348718  0.088570  0.055271
# 462686  0.620000  0.421053  0.550000    ...      0.235897  0.018561  0.072317
# 462687  0.642659  0.402402  0.597818    ...      0.256410  0.028655  0.072317
# 462688  0.800000  0.421053  0.562500    ...      0.205128  0.098339  0.078813
# 462689  0.642659  0.402402  0.597818    ...      0.202134  0.053197  0.072317
# 462690  0.642659  0.402402  0.597819    ...      0.202134  0.053197  0.072317
# 462691  0.700000  0.368421  0.597819    ...      0.202133  0.053197  0.071648
# 462692  0.860000  0.410526  0.562500    ...      0.179487  0.111690  0.072317
# 462693  0.642660  0.402402  0.597820    ...      0.202133  0.053197  0.072317
# 462694  0.642660  0.402402  0.597820    ...      0.143590  0.104852  0.061412
# 462695  0.642660  0.402402  0.597820    ...      0.153846  0.124064  0.072317
# 462696  0.642660  0.402402  0.597821    ...      0.328205  0.027027  0.072317
# 462697  0.642660  0.402402  0.597821    ...      0.202131  0.053197  0.072317
#
#          LR_CR  LR_GLUCNONFAST    LR_LDL    LR_GFR    LR_ALT  LR_GFR_AFRAMER  \
# 0       0.0110        0.071333  0.121507  0.304197  0.029271        0.276011
# 1       0.0110        0.080667  0.130600  0.304197  0.021084        0.276011
# 2       0.0100        0.078000  0.154313  0.304197  0.018072        0.276011
# 3       0.0105        0.074000  0.128797  0.304198  0.030120        0.276011
# 4       0.0113        0.068667  0.130600  0.304198  0.029270        0.276011
# 5       0.0099        0.072667  0.171324  0.283333  0.020080        0.270642
# 6       0.0110        0.061333  0.130600  0.304198  0.029270        0.276011
# 7       0.0103        0.071333  0.187120  0.304198  0.021084        0.276011
# 8       0.0103        0.071333  0.187120  0.304198  0.021084        0.276011
# 9       0.0117        0.057333  0.091130  0.304198  0.014056        0.276011
# 10      0.0111        0.054000  0.130600  0.255556  0.013052        0.243119
# 11      0.0104        0.061333  0.095990  0.304198  0.026104        0.276011
# 12      0.0120        0.058000  0.130600  0.304198  0.029270        0.276011
# 13      0.0130        0.062667  0.165249  0.304198  0.022088        0.276011
# 14      0.0130        0.062667  0.165249  0.304199  0.022088        0.276011
# 15      0.0100        0.060000  0.074119  0.304199  0.017068        0.276011
# 16      0.0110        0.084000  0.130600  0.304199  0.029270        0.276012
# 17      0.0100        0.062000  0.130600  0.304199  0.029270        0.276012
# 18      0.0128        0.059333  0.130600  0.304199  0.029270        0.276012
# 19      0.0110        0.068667  0.130600  0.304199  0.022088        0.276012
# 20      0.0120        0.067333  0.088700  0.304199  0.034137        0.276012
# 21      0.0110        0.052667  0.106926  0.304199  0.029270        0.276012
# 22      0.0100        0.076246  0.130600  0.304199  0.029270        0.276012
# 23      0.0120        0.060667  0.130600  0.304199  0.016064        0.276012
# 24      0.0113        0.051333  0.080194  0.304200  0.023092        0.276012
# 25      0.0112        0.062667  0.130600  0.304200  0.022088        0.276012
# 26      0.0118        0.053333  0.130600  0.304200  0.018072        0.276012
# 27      0.0118        0.053333  0.130600  0.304200  0.018072        0.276012
# 28      0.0100        0.067333  0.130600  0.304200  0.042169        0.276012
# 29      0.0115        0.063333  0.145808  0.304200  0.016064        0.276012
# ...        ...             ...       ...       ...       ...             ...
# 462668  0.0133        0.057333  0.134872  0.272222  0.014056        0.261468
# 462669  0.0155        0.053333  0.121507  0.222222  0.015060        0.211009
# 462670  0.0136        0.078000  0.106209  0.266667  0.012048        0.256881
# 462671  0.0150        0.064667  0.106209  0.252667  0.028305        0.252431
# 462672  0.0150        0.064667  0.106209  0.252667  0.028305        0.252431
# 462673  0.0180        0.062000  0.106209  0.204611  0.028305        0.204404
# 462674  0.0192        0.062000  0.106209  0.183333  0.028305        0.174312
# 462675  0.0171        0.076667  0.106209  0.211111  0.028305        0.201835
# 462676  0.0202        0.083499  0.106209  0.161111  0.028305        0.155963
# 462677  0.0127        0.072000  0.115431  0.305556  0.013052        0.269036
# 462678  0.0136        0.069333  0.099635  0.283333  0.013052        0.270642
# 462679  0.0141        0.064667  0.106208  0.266667  0.012048        0.256881
# 462680  0.0133        0.067333  0.103281  0.288889  0.014056        0.275229
# 462681  0.0137        0.069333  0.098420  0.277778  0.014056        0.266055
# 462682  0.0136        0.068000  0.131227  0.294444  0.009036        0.284404
# 462683  0.0152        0.064000  0.106926  0.255556  0.010040        0.247706
# 462684  0.0156        0.065333  0.106208  0.250000  0.010040        0.238532
# 462685  0.0152        0.077333  0.121507  0.255556  0.011044        0.243119
# 462686  0.0121        0.058667  0.057108  0.327778  0.036145        0.311927
# 462687  0.0129        0.066000  0.065614  0.300000  0.025100        0.284404
# 462688  0.0212        0.109333  0.150668  0.172222  0.011044        0.174312
# 462689  0.0245        0.108667  0.106208  0.150000  0.028305        0.146789
# 462690  0.0226        0.110667  0.106208  0.161111  0.028305        0.160550
# 462691  0.0333        0.074667  0.106208  0.100000  0.528112        0.096330
# 462692  0.0214        0.071333  0.210207  0.172222  0.024096        0.165138
# 462693  0.0247        0.070000  0.106207  0.144444  0.028305        0.137615
# 462694  0.0260        0.074667  0.149453  0.138889  0.025100        0.133028
# 462695  0.0262        0.070667  0.130012  0.133333  0.028305        0.128440
# 462696  0.0119        0.069333  0.093560  0.327778  0.016064        0.316514
# 462697  0.9930        0.083500  0.106207  0.285089  0.028305        0.269034
#
#               gfr
# 0       46.662023
# 1       46.662023
# 2       52.087166
# 3       49.235491
# 4       45.235376
# 5       52.694794
# 6       48.687812
# 7       52.525870
# 8       52.525870
# 9       43.858349
# 10      46.605380
# 11      49.782219
# 12      44.946862
# 13      40.733527
# 14      40.733527
# 15      52.325329
# 16      46.875381
# 17      52.325329
# 18      39.354252
# 19      48.963150
# 20      44.285479
# 21      47.435332
# 22      52.950382
# 23      45.824960
# 24      48.476906
# 25      48.976734
# 26      46.882111
# 27       0.459047
# 28      54.348481
# 29      46.253234
# ...           ...
# 462668  54.314540
# 462669  45.096620
# 462670  52.808746
# 462671  47.982772
# 462672  47.982772
# 462673  38.878560
# 462674  36.088184
# 462675  41.249352
# 462676  33.297182
# 462677  58.294589
# 462678  53.865890
# 462679  51.667671
# 462680  55.270443
# 462681  53.412414
# 462682  54.748289
# 462683  48.153399
# 462684  46.731386
# 462685  48.153399
# 462686  61.642951
# 462687  57.252864
# 462688  32.988795
# 462689  27.916462
# 462690  30.641986
# 462691  19.591036
# 462692  32.633267
# 462693  27.655770
# 462694  26.066265
# 462695  25.836778
# 462696  62.677758
# 462697   0.480012
#
# [462698 rows x 21 columns]

# %%
plt.plot(interpolated_spline2['LR_CR'])
print "Creatinine levels after spline interpolation"
# Out:
# Creatinine levels after spline interpolation

# %% [markdown]
# #### Spline interpolations with order=3

# %%
current_method = 'spline'
interpolated_spline3 = combined_df.interpolate(method=current_method, order=3, limit_direction='both', limit=100000)

# %% [markdown]
# ### Check if there's any NaN values still remaining in any feature column

# %%
interpolated_spline3.isnull().sum()
# Out:
# pid               0
# timestamp         0
# gender            0
# birthyear         0
# age               0
# smoker_status     0
# FND_WTLB          0
# FND_BPS           0
# FND_BPD           0
# FND_HTIN          0
# LR_AST            0
# LR_HDL            0
# LR_TRIG           0
# LR_A1C            0
# LR_CR             0
# LR_GLUCNONFAST    0
# LR_LDL            0
# LR_GFR            0
# LR_ALT            0
# LR_GFR_AFRAMER    0
# gfr               0
# dtype: int64

# %%
combined_df
# Out:
#             pid   timestamp  gender  birthyear  age  smoker_status  FND_WTLB  \
# 0       8545332  2006-08-11       0       1924   90            0.5  0.191439
# 1       8545332  2006-11-02       0       1924   90            0.5  0.195832
# 2       8545332  2007-06-05       0       1924   90            0.5  0.197088
# 3       8545332  2010-02-09       0       1924   90            0.5  0.204620
# 4       8545332  2010-08-17       0       1924   90            0.5  0.203364
# 5       8545332  2011-04-13       0       1924   90            0.5  0.204620
# 6       8545333  2007-05-31       0       1941   73            0.0  0.184534
# 7       8545333  2010-06-10       0       1941   73            0.0       NaN
# 8       8545333  2010-06-10       0       1941   73            0.0       NaN
# 9       8545336  2010-11-18       0       1928   86            0.0  0.151896
# 10      8545336  2011-09-01       0       1928   86            0.0  0.141853
# 11      8545337  2010-10-29       0       1924   90            0.5       NaN
# 12      8545338  2007-10-11       0       1948   66            0.0  0.177002
# 13      8545339  2010-05-24       0       1946   68            0.0  0.338940
# 14      8545339  2010-05-24       0       1946   68            0.0  0.338940
# 15      8545340  2007-04-19       0       1926   88            0.0  0.177002
# 16      8545340  2007-10-01       0       1926   88            0.0  0.311323
# 17      8545340  2007-10-09       0       1926   88            0.0       NaN
# 18      8545340  2008-12-18       0       1926   88            0.0  0.188300
# 19      8545341  2006-12-06       0       1943   71            NaN  0.229726
# 20      8545341  2007-03-26       0       1943   71            NaN  0.237258
# 21      8545342  2007-02-20       0       1931   83            0.5  0.160683
# 22      8545342  2007-07-19       0       1931   83            0.5  0.160683
# 23      8545344  2007-11-26       0       1954   60            1.0  0.243535
# 24      8545345  2009-06-25       0       1950   64            0.5  0.370324
# 25      8545346  2009-01-15       0       1950   64            0.0  0.160683
# 26      8545347  2010-10-29       0       1955   59            0.0  0.220939
# 27      8545347  2010-10-29       0       1955   59            0.0  0.220939
# 28      8545348  2006-08-10       0       1941   73            0.0  0.247301
# 29      8545348  2009-05-04       0       1941   73            0.0  0.228471
# ...         ...         ...     ...        ...  ...            ...       ...
# 462668  9581789  2011-09-13       1       1929   85            NaN       NaN
# 462669  9581790  2011-05-06       1       1925   89            NaN  0.134323
# 462670  9581791  2011-08-29       1       1928   86            NaN       NaN
# 462671  9581793  2011-09-02       1       1935   79            0.5       NaN
# 462672  9581793  2011-09-02       1       1935   79            0.5       NaN
# 462673  9581793  2011-11-08       1       1935   79            0.5       NaN
# 462674  9581793  2012-02-15       1       1935   79            0.5       NaN
# 462675  9581793  2012-03-01       1       1935   79            0.5       NaN
# 462676  9581799  2011-06-24       1       1926   88            NaN       NaN
# 462677  9581800  2011-01-06       1       1936   78            NaN       NaN
# 462678  9581800  2011-03-08       1       1936   78            NaN       NaN
# 462679  9581800  2011-08-08       1       1936   78            NaN       NaN
# 462680  9581800  2011-10-18       1       1936   78            NaN       NaN
# 462681  9581800  2012-01-24       1       1936   78            NaN       NaN
# 462682  9581801  2011-03-30       1       1942   72            NaN       NaN
# 462683  9581801  2011-07-20       1       1942   72            NaN       NaN
# 462684  9581801  2011-08-16       1       1942   72            NaN       NaN
# 462685  9581801  2011-11-19       1       1942   72            NaN       NaN
# 462686  9581803  2011-03-16       1       1936   78            NaN  0.200857
# 462687  9581803  2011-11-01       1       1936   78            NaN       NaN
# 462688  9581807  2010-10-29       1       1944   70            NaN  0.338946
# 462689  9581807  2010-11-10       1       1944   70            NaN       NaN
# 462690  9581807  2010-11-23       1       1944   70            NaN       NaN
# 462691  9581807  2011-03-08       1       1944   70            NaN  0.343967
# 462692  9581807  2011-03-30       1       1944   70            NaN  0.346479
# 462693  9581807  2011-04-18       1       1944   70            NaN       NaN
# 462694  9581807  2011-06-07       1       1944   70            NaN       NaN
# 462695  9581807  2011-08-05       1       1944   70            NaN       NaN
# 462696  9581811  2011-04-15       1       1935   79            NaN       NaN
# 462697  9581815  2012-03-01       1       1989   25            NaN       NaN
#
#         FND_BPS   FND_BPD  FND_HTIN    ...        LR_HDL   LR_TRIG    LR_A1C  \
# 0         0.600  0.368421       NaN    ...      0.235897  0.061218       NaN
# 1         0.590  0.368421       NaN    ...           NaN       NaN       NaN
# 2         0.750  0.368421  0.533333    ...      0.220513  0.053077       NaN
# 3         0.820  0.363158  0.533333    ...      0.215385  0.073917       NaN
# 4         0.675  0.410526  0.533333    ...           NaN       NaN       NaN
# 5         0.730  0.342105  0.533333    ...      0.097436  0.071638       NaN
# 6         0.650  0.368421       NaN    ...           NaN       NaN       NaN
# 7           NaN       NaN       NaN    ...      0.220513  0.055031       NaN
# 8           NaN       NaN       NaN    ...      0.220513  0.055031       NaN
# 9         0.735  0.431579  0.520833    ...      0.405128  0.109736       NaN
# 10        0.575  0.215789  0.520833    ...           NaN       NaN       NaN
# 11        0.600  0.389474  0.516667    ...      0.312821  0.033865       NaN
# 12        0.700  0.421053  0.558333    ...           NaN       NaN       NaN
# 13        0.775  0.394737  0.554167    ...      0.215385  0.075220       NaN
# 14        0.775  0.394737  0.554167    ...      0.215385  0.075220       NaN
# 15        0.700  0.421053  0.522917    ...      0.205128  0.053077       NaN
# 16        0.700  0.421053  0.522917    ...           NaN       NaN       NaN
# 17          NaN       NaN       NaN    ...           NaN       NaN       NaN
# 18          NaN       NaN  0.522917    ...           NaN       NaN       NaN
# 19        0.660  0.410526       NaN    ...           NaN       NaN       NaN
# 20        0.590  0.368421       NaN    ...      0.282051  0.093781       NaN
# 21        0.530  0.294737  0.516667    ...      0.389744  0.055031       NaN
# 22        0.560  0.336842  0.516667    ...           NaN       NaN       NaN
# 23        0.640  0.410526  0.600000    ...           NaN       NaN       NaN
# 24        0.530  0.373684  0.575000    ...      0.307692  0.065451  0.064483
# 25        0.695  0.468421  0.541667    ...           NaN       NaN       NaN
# 26        0.615  0.368421  0.529167    ...           NaN       NaN       NaN
# 27        0.615  0.368421  0.529167    ...           NaN       NaN       NaN
# 28        0.900  0.473684       NaN    ...           NaN       NaN       NaN
# 29        0.685  0.347368  0.533333    ...      0.369231  0.048844       NaN
# ...         ...       ...       ...    ...           ...       ...       ...
# 462668      NaN       NaN       NaN    ...      0.261538  0.042006       NaN
# 462669    0.600  0.336842  0.516667    ...      0.379487  0.018886       NaN
# 462670      NaN       NaN       NaN    ...           NaN       NaN       NaN
# 462671      NaN       NaN       NaN    ...           NaN       NaN       NaN
# 462672      NaN       NaN       NaN    ...           NaN       NaN       NaN
# 462673      NaN       NaN       NaN    ...           NaN       NaN       NaN
# 462674      NaN       NaN       NaN    ...           NaN       NaN       NaN
# 462675      NaN       NaN       NaN    ...           NaN       NaN       NaN
# 462676      NaN       NaN       NaN    ...           NaN       NaN       NaN
# 462677      NaN       NaN       NaN    ...      0.271795  0.023445  0.067554
# 462678      NaN       NaN       NaN    ...      0.261538  0.024422  0.064483
# 462679      NaN       NaN       NaN    ...           NaN       NaN  0.064483
# 462680      NaN       NaN       NaN    ...      0.302564  0.026376  0.066530
# 462681      NaN       NaN       NaN    ...      0.302564  0.021166  0.067554
# 462682      NaN       NaN       NaN    ...      0.302564  0.063497       NaN
# 462683      NaN       NaN       NaN    ...      0.302564  0.092804  0.055271
# 462684      NaN       NaN       NaN    ...           NaN       NaN       NaN
# 462685      NaN       NaN       NaN    ...      0.348718  0.088570  0.055271
# 462686    0.620  0.421053  0.550000    ...      0.235897  0.018561       NaN
# 462687      NaN       NaN       NaN    ...      0.256410  0.028655       NaN
# 462688    0.800  0.421053  0.562500    ...      0.205128  0.098339  0.078813
# 462689      NaN       NaN       NaN    ...           NaN       NaN       NaN
# 462690      NaN       NaN       NaN    ...           NaN       NaN       NaN
# 462691    0.700  0.368421       NaN    ...           NaN       NaN  0.071648
# 462692    0.860  0.410526  0.562500    ...      0.179487  0.111690       NaN
# 462693      NaN       NaN       NaN    ...           NaN       NaN       NaN
# 462694      NaN       NaN       NaN    ...      0.143590  0.104852  0.061412
# 462695      NaN       NaN       NaN    ...      0.153846  0.124064       NaN
# 462696      NaN       NaN       NaN    ...      0.328205  0.027027       NaN
# 462697      NaN       NaN       NaN    ...           NaN       NaN       NaN
#
#          LR_CR  LR_GLUCNONFAST    LR_LDL    LR_GFR    LR_ALT  LR_GFR_AFRAMER  \
# 0       0.0110        0.071333  0.121507       NaN       NaN             NaN
# 1       0.0110        0.080667       NaN       NaN  0.021084             NaN
# 2       0.0100        0.078000  0.154313       NaN  0.018072             NaN
# 3       0.0105        0.074000  0.128797       NaN  0.030120             NaN
# 4       0.0113        0.068667       NaN       NaN       NaN             NaN
# 5       0.0099        0.072667  0.171324  0.283333  0.020080        0.270642
# 6       0.0110        0.061333       NaN       NaN       NaN             NaN
# 7       0.0103        0.071333  0.187120       NaN  0.021084             NaN
# 8       0.0103        0.071333  0.187120       NaN  0.021084             NaN
# 9       0.0117        0.057333  0.091130       NaN  0.014056             NaN
# 10      0.0111        0.054000       NaN  0.255556  0.013052        0.243119
# 11      0.0104        0.061333  0.095990       NaN  0.026104             NaN
# 12      0.0120        0.058000       NaN       NaN       NaN             NaN
# 13      0.0130        0.062667  0.165249       NaN  0.022088             NaN
# 14      0.0130        0.062667  0.165249       NaN  0.022088             NaN
# 15      0.0100        0.060000  0.074119       NaN  0.017068             NaN
# 16      0.0110        0.084000       NaN       NaN       NaN             NaN
# 17      0.0100        0.062000       NaN       NaN       NaN             NaN
# 18      0.0128        0.059333       NaN       NaN       NaN             NaN
# 19      0.0110        0.068667       NaN       NaN  0.022088             NaN
# 20      0.0120        0.067333  0.088700       NaN  0.034137             NaN
# 21      0.0110        0.052667  0.106926       NaN       NaN             NaN
# 22      0.0100             NaN       NaN       NaN       NaN             NaN
# 23      0.0120        0.060667       NaN       NaN  0.016064             NaN
# 24      0.0113        0.051333  0.080194       NaN  0.023092             NaN
# 25      0.0112        0.062667       NaN       NaN  0.022088             NaN
# 26      0.0118        0.053333       NaN       NaN  0.018072             NaN
# 27      0.0118        0.053333       NaN       NaN  0.018072             NaN
# 28      0.0100        0.067333       NaN       NaN  0.042169             NaN
# 29      0.0115        0.063333  0.145808       NaN  0.016064             NaN
# ...        ...             ...       ...       ...       ...             ...
# 462668  0.0133        0.057333  0.134872  0.272222  0.014056        0.261468
# 462669  0.0155        0.053333  0.121507  0.222222  0.015060        0.211009
# 462670  0.0136        0.078000       NaN  0.266667  0.012048        0.256881
# 462671  0.0150        0.064667       NaN  0.252667       NaN        0.252431
# 462672  0.0150        0.064667       NaN  0.252667       NaN        0.252431
# 462673  0.0180        0.062000       NaN  0.204611       NaN        0.204404
# 462674  0.0192        0.062000       NaN  0.183333       NaN        0.174312
# 462675  0.0171        0.076667       NaN  0.211111       NaN        0.201835
# 462676  0.0202             NaN       NaN  0.161111       NaN        0.155963
# 462677  0.0127        0.072000  0.115431  0.305556  0.013052             NaN
# 462678  0.0136        0.069333  0.099635  0.283333  0.013052        0.270642
# 462679  0.0141        0.064667       NaN  0.266667  0.012048        0.256881
# 462680  0.0133        0.067333  0.103281  0.288889  0.014056        0.275229
# 462681  0.0137        0.069333  0.098420  0.277778  0.014056        0.266055
# 462682  0.0136        0.068000  0.131227  0.294444  0.009036        0.284404
# 462683  0.0152        0.064000  0.106926  0.255556  0.010040        0.247706
# 462684  0.0156        0.065333       NaN  0.250000  0.010040        0.238532
# 462685  0.0152        0.077333  0.121507  0.255556  0.011044        0.243119
# 462686  0.0121        0.058667  0.057108  0.327778  0.036145        0.311927
# 462687  0.0129        0.066000  0.065614  0.300000  0.025100        0.284404
# 462688  0.0212        0.109333  0.150668  0.172222  0.011044        0.174312
# 462689  0.0245        0.108667       NaN  0.150000       NaN        0.146789
# 462690  0.0226        0.110667       NaN  0.161111       NaN        0.160550
# 462691  0.0333        0.074667       NaN  0.100000  0.528112        0.096330
# 462692  0.0214        0.071333  0.210207  0.172222  0.024096        0.165138
# 462693  0.0247        0.070000       NaN  0.144444       NaN        0.137615
# 462694  0.0260        0.074667  0.149453  0.138889  0.025100        0.133028
# 462695  0.0262        0.070667  0.130012  0.133333       NaN        0.128440
# 462696  0.0119        0.069333  0.093560  0.327778  0.016064        0.316514
# 462697  0.9930             NaN       NaN       NaN       NaN             NaN
#
#               gfr
# 0       46.662023
# 1       46.662023
# 2       52.087166
# 3       49.235491
# 4       45.235376
# 5       52.694794
# 6       48.687812
# 7       52.525870
# 8       52.525870
# 9       43.858349
# 10      46.605380
# 11      49.782219
# 12      44.946862
# 13      40.733527
# 14      40.733527
# 15      52.325329
# 16      46.875381
# 17      52.325329
# 18      39.354252
# 19      48.963150
# 20      44.285479
# 21      47.435332
# 22      52.950382
# 23      45.824960
# 24      48.476906
# 25      48.976734
# 26      46.882111
# 27       0.459047
# 28      54.348481
# 29      46.253234
# ...           ...
# 462668  54.314540
# 462669  45.096620
# 462670  52.808746
# 462671  47.982772
# 462672  47.982772
# 462673  38.878560
# 462674  36.088184
# 462675  41.249352
# 462676  33.297182
# 462677  58.294589
# 462678  53.865890
# 462679  51.667671
# 462680  55.270443
# 462681  53.412414
# 462682  54.748289
# 462683  48.153399
# 462684  46.731386
# 462685  48.153399
# 462686  61.642951
# 462687  57.252864
# 462688  32.988795
# 462689  27.916462
# 462690  30.641986
# 462691  19.591036
# 462692  32.633267
# 462693  27.655770
# 462694  26.066265
# 462695  25.836778
# 462696  62.677758
# 462697   0.480012
#
# [462698 rows x 21 columns]

# %% [markdown]
# ### Write the interpolated values to a csv

# %%
# Spline interpolation with order=2
output_file_path = 'combined_df_spline2.csv'
interpolated_spline2.to_csv(output_file_path, sep='\t')

# Spline interpolation with order=3
output_file_path = 'combined_df_spline3.csv'
interpolated_spline3.to_csv(output_file_path, sep='\t')
